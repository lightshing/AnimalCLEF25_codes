# %%
# !pip install git+https://github.com/WildlifeDatasets/wildlife-datasets@develop
# !pip install git+https://github.com/lightshing/wildlife-tools
# !pip install pytorch-metric-learning
# !pip install umap-learn
# !pip install umap
# !pip install record-keeper
# !pip install faiss-cpu

# %%
import os
import numpy as np
import pandas as pd
import timm
import torchvision.transforms as T
import torch
from torch import nn
from torch import optim
from torch.utils.tensorboard import SummaryWriter
from datetime import datetime
from wildlife_datasets.datasets import AnimalCLEF2025
from wildlife_datasets import splits
from sklearn.preprocessing import LabelEncoder

# %matplotlib inline
import logging



from pytorch_metric_learning import distances, reducers

import pytorch_metric_learning
from pytorch_metric_learning import losses, miners, samplers
from pytorch_metric_learning.utils.accuracy_calculator import AccuracyCalculator
import pytorch_metric_learning.utils.logging_presets as LP
from pytorch_metric_learning.trainers import TrainWithClassifier
from pytorch_metric_learning.testers import BaseTester
import torch
import os


logging.getLogger().setLevel(logging.INFO)
logging.info("VERSION %s" % pytorch_metric_learning.__version__)
# Out:
# 2025-05-03 18:25:26.685205: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1746296726.875448      19 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1746296726.928503      19 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
root = '/kaggle/input/offline-imgaug/aug'
out_root = '/kaggle/working'
checkpoint_out_path = '/kaggle/working/model_checkpoints'

# %%
set_split_seed = 333
training_seed = 666
batch_size = 16
Vmargin = 0.22

# %%
name = 'hf-hub:BVRA/MegaDescriptor-L-384'
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
mega = timm.create_model(name, num_classes=0, pretrained=True)
print(device)
mega = mega.to(device)
# Out:
# config.json:   0%|          | 0.00/609 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/1.94G [00:00<?, ?B/s]
# cuda

# %%
transform_mega_ori = timm.data.create_transform(
    **timm.data.resolve_data_config(mega.pretrained_cfg)
)
transform_mega_ori
# Out:
# Compose(
#     Resize(size=426, interpolation=bicubic, max_size=None, antialias=True)
#     CenterCrop(size=(384, 384))
#     MaybeToTensor()
#     Normalize(mean=tensor([0.4850, 0.4560, 0.4060]), std=tensor([0.2290, 0.2240, 0.2250]))
# )

# %%
transform = T.Compose([
    T.ToTensor(),
    *transform_mega_ori.transforms
    ])

# %%
# Loading the dataset
dataset = AnimalCLEF2025(root, transform=transform, load_label=True)
dataset_database = dataset.get_subset(dataset.metadata['split'] == 'database')
dataset_query = dataset.get_subset(dataset.metadata['split'] == 'query')
n_query = len(dataset_query)

# %%
dataset.metadata[['dataset', 'split']].value_counts()
# Out:
# dataset           split
# SeaTurtleID2022   database    8821
# SalamanderID2025  database    3064
# LynxID2025        database    3006
#                   query        946
# SalamanderID2025  query        689
# SeaTurtleID2022   query        500
# Name: count, dtype: int64

# %%
dataset_database.df
# Out:
#        image_id              identity  \
# 0             0    LynxID2025_lynx_37
# 1             1    LynxID2025_lynx_37
# 2             2    LynxID2025_lynx_49
# 3             4    LynxID2025_lynx_13
# 4             6    LynxID2025_lynx_07
# ...         ...                   ...
# 14886     17021  SalamanderID2025_647
# 14887     17022  SalamanderID2025_507
# 14888     17023  SalamanderID2025_507
# 14889     17024  SalamanderID2025_507
# 14890     17025  SalamanderID2025_507
#
#                                                     path        date  \
# 0                       images/LynxID2025/database/0.jpg         NaN
# 1                       images/LynxID2025/database/1.jpg         NaN
# 2                       images/LynxID2025/database/2.jpg         NaN
# 3                       images/LynxID2025/database/4.jpg         NaN
# 4                       images/LynxID2025/database/6.jpg         NaN
# ...                                                  ...         ...
# 14886  images/SalamanderID2025/database/images/17021.jpg  2024-10-02
# 14887  images/SalamanderID2025/database/images/17022.jpg  2023-09-22
# 14888  images/SalamanderID2025/database/images/17023.jpg  2023-09-22
# 14889  images/SalamanderID2025/database/images/17024.jpg  2023-09-22
# 14890  images/SalamanderID2025/database/images/17025.jpg  2023-09-22
#
#       orientation species     split           dataset
# 0           right    lynx  database        LynxID2025
# 1            left    lynx  database        LynxID2025
# 2            left    lynx  database        LynxID2025
# 3           right    lynx  database        LynxID2025
# 4            left    lynx  database        LynxID2025
# ...           ...     ...       ...               ...
# 14886         top     NaN  database  SalamanderID2025
# 14887       right     NaN  database  SalamanderID2025
# 14888       right     NaN  database  SalamanderID2025
# 14889       right     NaN  database  SalamanderID2025
# 14890       right     NaN  database  SalamanderID2025
#
# [14891 rows x 8 columns]

# %% [markdown]
# ### Split
# train/test/thresholdSet/testSet

# %%
df_database = dataset_database.df
df_database.dataset.value_counts()
# Out:
# dataset
# SeaTurtleID2022     8821
# SalamanderID2025    3064
# LynxID2025          3006
# Name: count, dtype: int64

# %%
openSplitter = splits.OpenSetSplit(0.9, 0.1, seed=set_split_seed)
for idx_train, idx_test in openSplitter.split(df_database):
    splits.analyze_split(df_database, idx_train, idx_test)
# Out:
# Split: time-unaware open-set
# Samples: train/test/unassigned/total = 12399/2492/0/14891
# Classes: train/test/unassigned/total = 1002/1102/0/1102
# Samples: train only/test only        = 0/1490
# Classes: train only/test only/joint  = 0/100/1002
#
# Fraction of train set     = 83.27%
# Fraction of test set only = 10.01%

# %%
df_train, df_test = df_database.loc[idx_train], df_database.loc[idx_test]
print(len(df_train))
print(len(df_test))
# Out:
# 12399
# 2492

# %%
availableSet = dataset_database.get_subset(df_train.index)
testSet = dataset_database.get_subset(df_test.index)

# %%
df_availableSet = availableSet.df
df_availableSet.dataset.value_counts()
# Out:
# dataset
# SeaTurtleID2022     7617
# LynxID2025          2533
# SalamanderID2025    2249
# Name: count, dtype: int64

# %%
openSplitter = splits.OpenSetSplit(0.9, 0.1, seed=set_split_seed)
for idx_train, idx_test in openSplitter.split(df_availableSet):
    splits.analyze_split(df_availableSet, idx_train, idx_test)
# Out:
# Split: time-unaware open-set
# Samples: train/test/unassigned/total = 10244/2155/0/12399
# Classes: train/test/unassigned/total = 912/1002/0/1002
# Samples: train only/test only        = 0/1243
# Classes: train only/test only/joint  = 0/90/912
#
# Fraction of train set     = 82.62%
# Fraction of test set only = 10.03%

# %%
df_train, df_test = df_availableSet.loc[idx_train], df_availableSet.loc[idx_test]
print(len(df_train))
print(len(df_test))
# Out:
# 10244
# 2155

# %%
trainSet = availableSet.get_subset(df_train.index)
thresholdSet = availableSet.get_subset(df_test.index)

# %% [markdown]
# #### label: names to numbers

# %%
df_database_training = trainSet.df

df_database_training['name'] = df_database_training['identity'].copy()

encoder = LabelEncoder()
df_database_training['identity'] = encoder.fit_transform(df_database_training['identity'])

trainSet.df = df_database_training

# %%
df_database_training.to_csv("/kaggle/working/mm.csv", index=False, encoding='utf-8-sig')

# %%
df_database_training.dataset.value_counts()
# Out:
# dataset
# SeaTurtleID2022     6590
# LynxID2025          2101
# SalamanderID2025    1553
# Name: count, dtype: int64

# %%
closeSplitter = splits.ClosedSetSplit(0.9, seed=set_split_seed)
for idx_train, idx_test in closeSplitter.split(df_database_training):
    splits.analyze_split(df_database_training, idx_train, idx_test)
# Out:
# Split: time-unaware closed-set
# Samples: train/test/unassigned/total = 8802/1442/0/10244
# Classes: train/test/unassigned/total = 912/912/0/912
# Samples: train only/test only        = 0/0
# Classes: train only/test only/joint  = 0/0/912
#
# Fraction of train set     = 85.92%
# Fraction of test set only = 0.00%

# %%
df_training, df_val = df_database_training.loc[idx_train], df_database_training.loc[idx_test]
print(len(df_training))
print(len(df_val))
# Out:
# 8802
# 1442

# %%
training = trainSet.get_subset(df_training.index)
test = trainSet.get_subset(df_val.index)

# %%
training_labels = training.df["identity"].tolist()

# %%
df_of_training = training.df
df_of_training.dataset.value_counts()
# Out:
# dataset
# SeaTurtleID2022     5859
# LynxID2025          1874
# SalamanderID2025    1069
# Name: count, dtype: int64

# %%
closeSplitter = splits.ClosedSetSplit(0.1, seed=set_split_seed)
for idx_train, idx_test in closeSplitter.split(df_of_training):
    splits.analyze_split(df_of_training, idx_train, idx_test)
# Out:
# Split: time-unaware closed-set
# Samples: train/test/unassigned/total = 1371/7431/0/8802
# Classes: train/test/unassigned/total = 912/912/0/912
# Samples: train only/test only        = 0/0
# Classes: train only/test only/joint  = 0/0/912
#
# Fraction of train set     = 15.58%
# Fraction of test set only = 0.00%

# %%
df_training, df_val = df_of_training.loc[idx_train], df_of_training.loc[idx_test]
print(len(df_training))
print(len(df_val))
# Out:
# 1371
# 7431

# %%
subtraining = training.get_subset(df_training.index)

# %%
# trainloader = torch.utils.data.DataLoader(training, batch_size=batch_size, shuffle=True)
# testloader = torch.utils.data.DataLoader(test, batch_size=batch_size)

# %% [markdown]
# ### model

# %%
print(mega)
# Out:
# SwinTransformer(
#   (patch_embed): PatchEmbed(
#     (proj): Conv2d(3, 192, kernel_size=(4, 4), stride=(4, 4))
#     (norm): LayerNorm((192,), eps=1e-05, elementwise_affine=True)
#   )
#   (layers): Sequential(
#     (0): SwinTransformerStage(
#       (downsample): Identity()
#       (blocks): Sequential(
#         (0): SwinTransformerBlock(
#           (norm1): LayerNorm((192,), eps=1e-05, elementwise_affine=True)
#           (attn): WindowAttention(
#             (qkv): Linear(in_features=192, out_features=576, bias=True)
#             (attn_drop): Dropout(p=0.0, inplace=False)
#             (proj): Linear(in_features=192, out_features=192, bias=True)
#             (proj_drop): Dropout(p=0.0, inplace=False)
#             (softmax): Softmax(dim=-1)
#           )
#           (drop_path1): Identity()
#           (norm2): LayerNorm((192,), eps=1e-05, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=192, out_features=768, bias=True)
#             (act): GELU(approximate='none')
#             (drop1): Dropout(p=0.0, inplace=False)
#             (norm): Identity()
#             (fc2): Linear(in_features=768, out_features=192, bias=True)
#             (drop2): Dropout(p=0.0, inplace=False)
#           )
#           (drop_path2): Identity()
#         )
#         (1): SwinTransformerBlock(
#           (norm1): LayerNorm((192,), eps=1e-05, elementwise_affine=True)
#           (attn): WindowAttention(
#             (qkv): Linear(in_features=192, out_features=576, bias=True)
#             (attn_drop): Dropout(p=0.0, inplace=False)
#             (proj): Linear(in_features=192, out_features=192, bias=True)
#             (proj_drop): Dropout(p=0.0, inplace=False)
#             (softmax): Softmax(dim=-1)
#           )
#           (drop_path1): DropPath(drop_prob=0.004)
#           (norm2): LayerNorm((192,), eps=1e-05, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=192, out_features=768, bias=True)
#             (act): GELU(approximate='none')
#             (drop1): Dropout(p=0.0, inplace=False)
#             (norm): Identity()
#             (fc2): Linear(in_features=768, out_features=192, bias=True)
#             (drop2): Dropout(p=0.0, inplace=False)
#           )
#           (drop_path2): DropPath(drop_prob=0.004)
#         )
#       )
#     )
#     (1): SwinTransformerStage(
#       (downsample): PatchMerging(
#         (norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (reduction): Linear(in_features=768, out_features=384, bias=False)
#       )
#       (blocks): Sequential(
#         (0): SwinTransformerBlock(
#           (norm1): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#           (attn): WindowAttention(
#             (qkv): Linear(in_features=384, out_features=1152, bias=True)
#             (attn_drop): Dropout(p=0.0, inplace=False)
#             (proj): Linear(in_features=384, out_features=384, bias=True)
#             (proj_drop): Dropout(p=0.0, inplace=False)
#             (softmax): Softmax(dim=-1)
#           )
#           (drop_path1): DropPath(drop_prob=0.009)
#           (norm2): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=384, out_features=1536, bias=True)
#             (act): GELU(approximate='none')
#             (drop1): Dropout(p=0.0, inplace=False)
#             (norm): Identity()
#             (fc2): Linear(in_features=1536, out_features=384, bias=True)
#             (drop2): Dropout(p=0.0, inplace=False)
#           )
#           (drop_path2): DropPath(drop_prob=0.009)
#         )
#         (1): SwinTransformerBlock(
#           (norm1): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#           (attn): WindowAttention(
#             (qkv): Linear(in_features=384, out_features=1152, bias=True)
#             (attn_drop): Dropout(p=0.0, inplace=False)
#             (proj): Linear(in_features=384, out_features=384, bias=True)
#             (proj_drop): Dropout(p=0.0, inplace=False)
#             (softmax): Softmax(dim=-1)
#           )
#           (drop_path1): DropPath(drop_prob=0.013)
#           (norm2): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=384, out_features=1536, bias=True)
#             (act): GELU(approximate='none')
#             (drop1): Dropout(p=0.0, inplace=False)
#             (norm): Identity()
#             (fc2): Linear(in_features=1536, out_features=384, bias=True)
#             (drop2): Dropout(p=0.0, inplace=False)
#           )
#           (drop_path2): DropPath(drop_prob=0.013)
#         )
#       )
#     )
#     (2): SwinTransformerStage(
#       (downsample): PatchMerging(
#         (norm): LayerNorm((1536,), eps=1e-05, elementwise_affine=True)
#         (reduction): Linear(in_features=1536, out_features=768, bias=False)
#       )
#       (blocks): Sequential(
#         (0): SwinTransformerBlock(
#           (norm1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (attn): WindowAttention(
#             (qkv): Linear(in_features=768, out_features=2304, bias=True)
#             (attn_drop): Dropout(p=0.0, inplace=False)
#             (proj): Linear(in_features=768, out_features=768, bias=True)
#             (proj_drop): Dropout(p=0.0, inplace=False)
#             (softmax): Softmax(dim=-1)
#           )
#           (drop_path1): DropPath(drop_prob=0.017)
#           (norm2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=768, out_features=3072, bias=True)
#             (act): GELU(approximate='none')
#             (drop1): Dropout(p=0.0, inplace=False)
#             (norm): Identity()
#             (fc2): Linear(in_features=3072, out_features=768, bias=True)
#             (drop2): Dropout(p=0.0, inplace=False)
#           )
#           (drop_path2): DropPath(drop_prob=0.017)
#         )
#         (1): SwinTransformerBlock(
#           (norm1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (attn): WindowAttention(
#             (qkv): Linear(in_features=768, out_features=2304, bias=True)
#             (attn_drop): Dropout(p=0.0, inplace=False)
#             (proj): Linear(in_features=768, out_features=768, bias=True)
#             (proj_drop): Dropout(p=0.0, inplace=False)
#             (softmax): Softmax(dim=-1)
#           )
#           (drop_path1): DropPath(drop_prob=0.022)
#           (norm2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=768, out_features=3072, bias=True)
#             (act): GELU(approximate='none')
#             (drop1): Dropout(p=0.0, inplace=False)
#             (norm): Identity()
#             (fc2): Linear(in_features=3072, out_features=768, bias=True)
#             (drop2): Dropout(p=0.0, inplace=False)
#           )
#           (drop_path2): DropPath(drop_prob=0.022)
#         )
#         (2): SwinTransformerBlock(
#           (norm1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (attn): WindowAttention(
#             (qkv): Linear(in_features=768, out_features=2304, bias=True)
#             (attn_drop): Dropout(p=0.0, inplace=False)
#             (proj): Linear(in_features=768, out_features=768, bias=True)
#             (proj_drop): Dropout(p=0.0, inplace=False)
#             (softmax): Softmax(dim=-1)
#           )
#           (drop_path1): DropPath(drop_prob=0.026)
#           (norm2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=768, out_features=3072, bias=True)
#             (act): GELU(approximate='none')
#             (drop1): Dropout(p=0.0, inplace=False)
#             (norm): Identity()
#             (fc2): Linear(in_features=3072, out_features=768, bias=True)
#             (drop2): Dropout(p=0.0, inplace=False)
#           )
#           (drop_path2): DropPath(drop_prob=0.026)
#         )
#         (3): SwinTransformerBlock(
#           (norm1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (attn): WindowAttention(
#             (qkv): Linear(in_features=768, out_features=2304, bias=True)
#             (attn_drop): Dropout(p=0.0, inplace=False)
#             (proj): Linear(in_features=768, out_features=768, bias=True)
#             (proj_drop): Dropout(p=0.0, inplace=False)
#             (softmax): Softmax(dim=-1)
#           )
#           (drop_path1): DropPath(drop_prob=0.030)
#           (norm2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=768, out_features=3072, bias=True)
#             (act): GELU(approximate='none')
#             (drop1): Dropout(p=0.0, inplace=False)
#             (norm): Identity()
#             (fc2): Linear(in_features=3072, out_features=768, bias=True)
#             (drop2): Dropout(p=0.0, inplace=False)
#           )
#           (drop_path2): DropPath(drop_prob=0.030)
#         )
#         (4): SwinTransformerBlock(
#           (norm1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (attn): WindowAttention(
#             (qkv): Linear(in_features=768, out_features=2304, bias=True)
#             (attn_drop): Dropout(p=0.0, inplace=False)
#             (proj): Linear(in_features=768, out_features=768, bias=True)
#             (proj_drop): Dropout(p=0.0, inplace=False)
#             (softmax): Softmax(dim=-1)
#           )
#           (drop_path1): DropPath(drop_prob=0.035)
#           (norm2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=768, out_features=3072, bias=True)
#             (act): GELU(approximate='none')
#             (drop1): Dropout(p=0.0, inplace=False)
#             (norm): Identity()
#             (fc2): Linear(in_features=3072, out_features=768, bias=True)
#             (drop2): Dropout(p=0.0, inplace=False)
#           )
#           (drop_path2): DropPath(drop_prob=0.035)
#         )
#         (5): SwinTransformerBlock(
#           (norm1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (attn): WindowAttention(
#             (qkv): Linear(in_features=768, out_features=2304, bias=True)
#             (attn_drop): Dropout(p=0.0, inplace=False)
#             (proj): Linear(in_features=768, out_features=768, bias=True)
#             (proj_drop): Dropout(p=0.0, inplace=False)
#             (softmax): Softmax(dim=-1)
#           )
#           (drop_path1): DropPath(drop_prob=0.039)
#           (norm2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=768, out_features=3072, bias=True)
#             (act): GELU(approximate='none')
#             (drop1): Dropout(p=0.0, inplace=False)
#             (norm): Identity()
#             (fc2): Linear(in_features=3072, out_features=768, bias=True)
#             (drop2): Dropout(p=0.0, inplace=False)
#           )
#           (drop_path2): DropPath(drop_prob=0.039)
#         )
#         (6): SwinTransformerBlock(
#           (norm1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (attn): WindowAttention(
#             (qkv): Linear(in_features=768, out_features=2304, bias=True)
#             (attn_drop): Dropout(p=0.0, inplace=False)
#             (proj): Linear(in_features=768, out_features=768, bias=True)
#             (proj_drop): Dropout(p=0.0, inplace=False)
#             (softmax): Softmax(dim=-1)
#           )
#           (drop_path1): DropPath(drop_prob=0.043)
#           (norm2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=768, out_features=3072, bias=True)
#             (act): GELU(approximate='none')
#             (drop1): Dropout(p=0.0, inplace=False)
#             (norm): Identity()
#             (fc2): Linear(in_features=3072, out_features=768, bias=True)
#             (drop2): Dropout(p=0.0, inplace=False)
#           )
#           (drop_path2): DropPath(drop_prob=0.043)
#         )
#         (7): SwinTransformerBlock(
#           (norm1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (attn): WindowAttention(
#             (qkv): Linear(in_features=768, out_features=2304, bias=True)
#             (attn_drop): Dropout(p=0.0, inplace=False)
#             (proj): Linear(in_features=768, out_features=768, bias=True)
#             (proj_drop): Dropout(p=0.0, inplace=False)
#             (softmax): Softmax(dim=-1)
#           )
#           (drop_path1): DropPath(drop_prob=0.048)
#           (norm2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=768, out_features=3072, bias=True)
#             (act): GELU(approximate='none')
#             (drop1): Dropout(p=0.0, inplace=False)
#             (norm): Identity()
#             (fc2): Linear(in_features=3072, out_features=768, bias=True)
#             (drop2): Dropout(p=0.0, inplace=False)
#           )
#           (drop_path2): DropPath(drop_prob=0.048)
#         )
#         (8): SwinTransformerBlock(
#           (norm1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (attn): WindowAttention(
#             (qkv): Linear(in_features=768, out_features=2304, bias=True)
#             (attn_drop): Dropout(p=0.0, inplace=False)
#             (proj): Linear(in_features=768, out_features=768, bias=True)
#             (proj_drop): Dropout(p=0.0, inplace=False)
#             (softmax): Softmax(dim=-1)
#           )
#           (drop_path1): DropPath(drop_prob=0.052)
#           (norm2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=768, out_features=3072, bias=True)
#             (act): GELU(approximate='none')
#             (drop1): Dropout(p=0.0, inplace=False)
#             (norm): Identity()
#             (fc2): Linear(in_features=3072, out_features=768, bias=True)
#             (drop2): Dropout(p=0.0, inplace=False)
#           )
#           (drop_path2): DropPath(drop_prob=0.052)
#         )
#         (9): SwinTransformerBlock(
#           (norm1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (attn): WindowAttention(
#             (qkv): Linear(in_features=768, out_features=2304, bias=True)
#             (attn_drop): Dropout(p=0.0, inplace=False)
#             (proj): Linear(in_features=768, out_features=768, bias=True)
#             (proj_drop): Dropout(p=0.0, inplace=False)
#             (softmax): Softmax(dim=-1)
#           )
#           (drop_path1): DropPath(drop_prob=0.057)
#           (norm2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=768, out_features=3072, bias=True)
#             (act): GELU(approximate='none')
#             (drop1): Dropout(p=0.0, inplace=False)
#             (norm): Identity()
#             (fc2): Linear(in_features=3072, out_features=768, bias=True)
#             (drop2): Dropout(p=0.0, inplace=False)
#           )
#           (drop_path2): DropPath(drop_prob=0.057)
#         )
#         (10): SwinTransformerBlock(
#           (norm1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (attn): WindowAttention(
#             (qkv): Linear(in_features=768, out_features=2304, bias=True)
#             (attn_drop): Dropout(p=0.0, inplace=False)
#             (proj): Linear(in_features=768, out_features=768, bias=True)
#             (proj_drop): Dropout(p=0.0, inplace=False)
#             (softmax): Softmax(dim=-1)
#           )
#           (drop_path1): DropPath(drop_prob=0.061)
#           (norm2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=768, out_features=3072, bias=True)
#             (act): GELU(approximate='none')
#             (drop1): Dropout(p=0.0, inplace=False)
#             (norm): Identity()
#             (fc2): Linear(in_features=3072, out_features=768, bias=True)
#             (drop2): Dropout(p=0.0, inplace=False)
#           )
#           (drop_path2): DropPath(drop_prob=0.061)
#         )
#         (11): SwinTransformerBlock(
#           (norm1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (attn): WindowAttention(
#             (qkv): Linear(in_features=768, out_features=2304, bias=True)
#             (attn_drop): Dropout(p=0.0, inplace=False)
#             (proj): Linear(in_features=768, out_features=768, bias=True)
#             (proj_drop): Dropout(p=0.0, inplace=False)
#             (softmax): Softmax(dim=-1)
#           )
#           (drop_path1): DropPath(drop_prob=0.065)
#           (norm2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=768, out_features=3072, bias=True)
#             (act): GELU(approximate='none')
#             (drop1): Dropout(p=0.0, inplace=False)
#             (norm): Identity()
#             (fc2): Linear(in_features=3072, out_features=768, bias=True)
#             (drop2): Dropout(p=0.0, inplace=False)
#           )
#           (drop_path2): DropPath(drop_prob=0.065)
#         )
#         (12): SwinTransformerBlock(
#           (norm1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (attn): WindowAttention(
#             (qkv): Linear(in_features=768, out_features=2304, bias=True)
#             (attn_drop): Dropout(p=0.0, inplace=False)
#             (proj): Linear(in_features=768, out_features=768, bias=True)
#             (proj_drop): Dropout(p=0.0, inplace=False)
#             (softmax): Softmax(dim=-1)
#           )
#           (drop_path1): DropPath(drop_prob=0.070)
#           (norm2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=768, out_features=3072, bias=True)
#             (act): GELU(approximate='none')
#             (drop1): Dropout(p=0.0, inplace=False)
#             (norm): Identity()
#             (fc2): Linear(in_features=3072, out_features=768, bias=True)
#             (drop2): Dropout(p=0.0, inplace=False)
#           )
#           (drop_path2): DropPath(drop_prob=0.070)
#         )
#         (13): SwinTransformerBlock(
#           (norm1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (attn): WindowAttention(
#             (qkv): Linear(in_features=768, out_features=2304, bias=True)
#             (attn_drop): Dropout(p=0.0, inplace=False)
#             (proj): Linear(in_features=768, out_features=768, bias=True)
#             (proj_drop): Dropout(p=0.0, inplace=False)
#             (softmax): Softmax(dim=-1)
#           )
#           (drop_path1): DropPath(drop_prob=0.074)
#           (norm2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=768, out_features=3072, bias=True)
#             (act): GELU(approximate='none')
#             (drop1): Dropout(p=0.0, inplace=False)
#             (norm): Identity()
#             (fc2): Linear(in_features=3072, out_features=768, bias=True)
#             (drop2): Dropout(p=0.0, inplace=False)
#           )
#           (drop_path2): DropPath(drop_prob=0.074)
#         )
#         (14): SwinTransformerBlock(
#           (norm1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (attn): WindowAttention(
#             (qkv): Linear(in_features=768, out_features=2304, bias=True)
#             (attn_drop): Dropout(p=0.0, inplace=False)
#             (proj): Linear(in_features=768, out_features=768, bias=True)
#             (proj_drop): Dropout(p=0.0, inplace=False)
#             (softmax): Softmax(dim=-1)
#           )
#           (drop_path1): DropPath(drop_prob=0.078)
#           (norm2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=768, out_features=3072, bias=True)
#             (act): GELU(approximate='none')
#             (drop1): Dropout(p=0.0, inplace=False)
#             (norm): Identity()
#             (fc2): Linear(in_features=3072, out_features=768, bias=True)
#             (drop2): Dropout(p=0.0, inplace=False)
#           )
#           (drop_path2): DropPath(drop_prob=0.078)
#         )
#         (15): SwinTransformerBlock(
#           (norm1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (attn): WindowAttention(
#             (qkv): Linear(in_features=768, out_features=2304, bias=True)
#             (attn_drop): Dropout(p=0.0, inplace=False)
#             (proj): Linear(in_features=768, out_features=768, bias=True)
#             (proj_drop): Dropout(p=0.0, inplace=False)
#             (softmax): Softmax(dim=-1)
#           )
#           (drop_path1): DropPath(drop_prob=0.083)
#           (norm2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=768, out_features=3072, bias=True)
#             (act): GELU(approximate='none')
#             (drop1): Dropout(p=0.0, inplace=False)
#             (norm): Identity()
#             (fc2): Linear(in_features=3072, out_features=768, bias=True)
#             (drop2): Dropout(p=0.0, inplace=False)
#           )
#           (drop_path2): DropPath(drop_prob=0.083)
#         )
#         (16): SwinTransformerBlock(
#           (norm1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (attn): WindowAttention(
#             (qkv): Linear(in_features=768, out_features=2304, bias=True)
#             (attn_drop): Dropout(p=0.0, inplace=False)
#             (proj): Linear(in_features=768, out_features=768, bias=True)
#             (proj_drop): Dropout(p=0.0, inplace=False)
#             (softmax): Softmax(dim=-1)
#           )
#           (drop_path1): DropPath(drop_prob=0.087)
#           (norm2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=768, out_features=3072, bias=True)
#             (act): GELU(approximate='none')
#             (drop1): Dropout(p=0.0, inplace=False)
#             (norm): Identity()
#             (fc2): Linear(in_features=3072, out_features=768, bias=True)
#             (drop2): Dropout(p=0.0, inplace=False)
#           )
#           (drop_path2): DropPath(drop_prob=0.087)
#         )
#         (17): SwinTransformerBlock(
#           (norm1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (attn): WindowAttention(
#             (qkv): Linear(in_features=768, out_features=2304, bias=True)
#             (attn_drop): Dropout(p=0.0, inplace=False)
#             (proj): Linear(in_features=768, out_features=768, bias=True)
#             (proj_drop): Dropout(p=0.0, inplace=False)
#             (softmax): Softmax(dim=-1)
#           )
#           (drop_path1): DropPath(drop_prob=0.091)
#           (norm2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=768, out_features=3072, bias=True)
#             (act): GELU(approximate='none')
#             (drop1): Dropout(p=0.0, inplace=False)
#             (norm): Identity()
#             (fc2): Linear(in_features=3072, out_features=768, bias=True)
#             (drop2): Dropout(p=0.0, inplace=False)
#           )
#           (drop_path2): DropPath(drop_prob=0.091)
#         )
#       )
#     )
#     (3): SwinTransformerStage(
#       (downsample): PatchMerging(
#         (norm): LayerNorm((3072,), eps=1e-05, elementwise_affine=True)
#         (reduction): Linear(in_features=3072, out_features=1536, bias=False)
#       )
#       (blocks): Sequential(
#         (0): SwinTransformerBlock(
#           (norm1): LayerNorm((1536,), eps=1e-05, elementwise_affine=True)
#           (attn): WindowAttention(
#             (qkv): Linear(in_features=1536, out_features=4608, bias=True)
#             (attn_drop): Dropout(p=0.0, inplace=False)
#             (proj): Linear(in_features=1536, out_features=1536, bias=True)
#             (proj_drop): Dropout(p=0.0, inplace=False)
#             (softmax): Softmax(dim=-1)
#           )
#           (drop_path1): DropPath(drop_prob=0.096)
#           (norm2): LayerNorm((1536,), eps=1e-05, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=1536, out_features=6144, bias=True)
#             (act): GELU(approximate='none')
#             (drop1): Dropout(p=0.0, inplace=False)
#             (norm): Identity()
#             (fc2): Linear(in_features=6144, out_features=1536, bias=True)
#             (drop2): Dropout(p=0.0, inplace=False)
#           )
#           (drop_path2): DropPath(drop_prob=0.096)
#         )
#         (1): SwinTransformerBlock(
#           (norm1): LayerNorm((1536,), eps=1e-05, elementwise_affine=True)
#           (attn): WindowAttention(
#             (qkv): Linear(in_features=1536, out_features=4608, bias=True)
#             (attn_drop): Dropout(p=0.0, inplace=False)
#             (proj): Linear(in_features=1536, out_features=1536, bias=True)
#             (proj_drop): Dropout(p=0.0, inplace=False)
#             (softmax): Softmax(dim=-1)
#           )
#           (drop_path1): DropPath(drop_prob=0.100)
#           (norm2): LayerNorm((1536,), eps=1e-05, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=1536, out_features=6144, bias=True)
#             (act): GELU(approximate='none')
#             (drop1): Dropout(p=0.0, inplace=False)
#             (norm): Identity()
#             (fc2): Linear(in_features=6144, out_features=1536, bias=True)
#             (drop2): Dropout(p=0.0, inplace=False)
#           )
#           (drop_path2): DropPath(drop_prob=0.100)
#         )
#       )
#     )
#   )
#   (norm): LayerNorm((1536,), eps=1e-05, elementwise_affine=True)
#   (head): ClassifierHead(
#     (global_pool): SelectAdaptivePool2d(pool_type=avg, flatten=Identity())
#     (drop): Dropout(p=0.0, inplace=False)
#     (fc): Identity()
#     (flatten): Identity()
#   )
# )

# %%
mega.head.drop = nn.Dropout(p=0.3)
mega.head.fc = nn.Linear(1536, 1024)

# %%
for name, param in mega.named_parameters():
    param.requires_grad = False
    if "norm.weight" == name:
        param.requires_grad = True
    if "norm.bias" == name:
        param.requires_grad = True
    if "layers.3" in name:
        param.requires_grad = True
    if "layers.2.blocks" in name:
        param.requires_grad = True
    if "head.fc" in name:
        param.requires_grad = True
for name, param in mega.named_parameters():
    print(f"{name}: {param.requires_grad}")
# Out:
# patch_embed.proj.weight: False
# patch_embed.proj.bias: False
# patch_embed.norm.weight: False
# patch_embed.norm.bias: False
# layers.0.blocks.0.norm1.weight: False
# layers.0.blocks.0.norm1.bias: False
# layers.0.blocks.0.attn.relative_position_bias_table: False
# layers.0.blocks.0.attn.qkv.weight: False
# layers.0.blocks.0.attn.qkv.bias: False
# layers.0.blocks.0.attn.proj.weight: False
# layers.0.blocks.0.attn.proj.bias: False
# layers.0.blocks.0.norm2.weight: False
# layers.0.blocks.0.norm2.bias: False
# layers.0.blocks.0.mlp.fc1.weight: False
# layers.0.blocks.0.mlp.fc1.bias: False
# layers.0.blocks.0.mlp.fc2.weight: False
# layers.0.blocks.0.mlp.fc2.bias: False
# layers.0.blocks.1.norm1.weight: False
# layers.0.blocks.1.norm1.bias: False
# layers.0.blocks.1.attn.relative_position_bias_table: False
# layers.0.blocks.1.attn.qkv.weight: False
# layers.0.blocks.1.attn.qkv.bias: False
# layers.0.blocks.1.attn.proj.weight: False
# layers.0.blocks.1.attn.proj.bias: False
# layers.0.blocks.1.norm2.weight: False
# layers.0.blocks.1.norm2.bias: False
# layers.0.blocks.1.mlp.fc1.weight: False
# layers.0.blocks.1.mlp.fc1.bias: False
# layers.0.blocks.1.mlp.fc2.weight: False
# layers.0.blocks.1.mlp.fc2.bias: False
# layers.1.downsample.norm.weight: False
# layers.1.downsample.norm.bias: False
# layers.1.downsample.reduction.weight: False
# layers.1.blocks.0.norm1.weight: False
# layers.1.blocks.0.norm1.bias: False
# layers.1.blocks.0.attn.relative_position_bias_table: False
# layers.1.blocks.0.attn.qkv.weight: False
# layers.1.blocks.0.attn.qkv.bias: False
# layers.1.blocks.0.attn.proj.weight: False
# layers.1.blocks.0.attn.proj.bias: False
# layers.1.blocks.0.norm2.weight: False
# layers.1.blocks.0.norm2.bias: False
# layers.1.blocks.0.mlp.fc1.weight: False
# layers.1.blocks.0.mlp.fc1.bias: False
# layers.1.blocks.0.mlp.fc2.weight: False
# layers.1.blocks.0.mlp.fc2.bias: False
# layers.1.blocks.1.norm1.weight: False
# layers.1.blocks.1.norm1.bias: False
# layers.1.blocks.1.attn.relative_position_bias_table: False
# layers.1.blocks.1.attn.qkv.weight: False
# layers.1.blocks.1.attn.qkv.bias: False
# layers.1.blocks.1.attn.proj.weight: False
# layers.1.blocks.1.attn.proj.bias: False
# layers.1.blocks.1.norm2.weight: False
# layers.1.blocks.1.norm2.bias: False
# layers.1.blocks.1.mlp.fc1.weight: False
# layers.1.blocks.1.mlp.fc1.bias: False
# layers.1.blocks.1.mlp.fc2.weight: False
# layers.1.blocks.1.mlp.fc2.bias: False
# layers.2.downsample.norm.weight: False
# layers.2.downsample.norm.bias: False
# layers.2.downsample.reduction.weight: False
# layers.2.blocks.0.norm1.weight: True
# layers.2.blocks.0.norm1.bias: True
# layers.2.blocks.0.attn.relative_position_bias_table: True
# layers.2.blocks.0.attn.qkv.weight: True
# layers.2.blocks.0.attn.qkv.bias: True
# layers.2.blocks.0.attn.proj.weight: True
# layers.2.blocks.0.attn.proj.bias: True
# layers.2.blocks.0.norm2.weight: True
# layers.2.blocks.0.norm2.bias: True
# layers.2.blocks.0.mlp.fc1.weight: True
# layers.2.blocks.0.mlp.fc1.bias: True
# layers.2.blocks.0.mlp.fc2.weight: True
# layers.2.blocks.0.mlp.fc2.bias: True
# layers.2.blocks.1.norm1.weight: True
# layers.2.blocks.1.norm1.bias: True
# layers.2.blocks.1.attn.relative_position_bias_table: True
# layers.2.blocks.1.attn.qkv.weight: True
# layers.2.blocks.1.attn.qkv.bias: True
# layers.2.blocks.1.attn.proj.weight: True
# layers.2.blocks.1.attn.proj.bias: True
# layers.2.blocks.1.norm2.weight: True
# layers.2.blocks.1.norm2.bias: True
# layers.2.blocks.1.mlp.fc1.weight: True
# layers.2.blocks.1.mlp.fc1.bias: True
# layers.2.blocks.1.mlp.fc2.weight: True
# layers.2.blocks.1.mlp.fc2.bias: True
# layers.2.blocks.2.norm1.weight: True
# layers.2.blocks.2.norm1.bias: True
# layers.2.blocks.2.attn.relative_position_bias_table: True
# layers.2.blocks.2.attn.qkv.weight: True
# layers.2.blocks.2.attn.qkv.bias: True
# layers.2.blocks.2.attn.proj.weight: True
# layers.2.blocks.2.attn.proj.bias: True
# layers.2.blocks.2.norm2.weight: True
# layers.2.blocks.2.norm2.bias: True
# layers.2.blocks.2.mlp.fc1.weight: True
# layers.2.blocks.2.mlp.fc1.bias: True
# layers.2.blocks.2.mlp.fc2.weight: True
# layers.2.blocks.2.mlp.fc2.bias: True
# layers.2.blocks.3.norm1.weight: True
# layers.2.blocks.3.norm1.bias: True
# layers.2.blocks.3.attn.relative_position_bias_table: True
# layers.2.blocks.3.attn.qkv.weight: True
# layers.2.blocks.3.attn.qkv.bias: True
# layers.2.blocks.3.attn.proj.weight: True
# layers.2.blocks.3.attn.proj.bias: True
# layers.2.blocks.3.norm2.weight: True
# layers.2.blocks.3.norm2.bias: True
# layers.2.blocks.3.mlp.fc1.weight: True
# layers.2.blocks.3.mlp.fc1.bias: True
# layers.2.blocks.3.mlp.fc2.weight: True
# layers.2.blocks.3.mlp.fc2.bias: True
# layers.2.blocks.4.norm1.weight: True
# layers.2.blocks.4.norm1.bias: True
# layers.2.blocks.4.attn.relative_position_bias_table: True
# layers.2.blocks.4.attn.qkv.weight: True
# layers.2.blocks.4.attn.qkv.bias: True
# layers.2.blocks.4.attn.proj.weight: True
# layers.2.blocks.4.attn.proj.bias: True
# layers.2.blocks.4.norm2.weight: True
# layers.2.blocks.4.norm2.bias: True
# layers.2.blocks.4.mlp.fc1.weight: True
# layers.2.blocks.4.mlp.fc1.bias: True
# layers.2.blocks.4.mlp.fc2.weight: True
# layers.2.blocks.4.mlp.fc2.bias: True
# layers.2.blocks.5.norm1.weight: True
# layers.2.blocks.5.norm1.bias: True
# layers.2.blocks.5.attn.relative_position_bias_table: True
# layers.2.blocks.5.attn.qkv.weight: True
# layers.2.blocks.5.attn.qkv.bias: True
# layers.2.blocks.5.attn.proj.weight: True
# layers.2.blocks.5.attn.proj.bias: True
# layers.2.blocks.5.norm2.weight: True
# layers.2.blocks.5.norm2.bias: True
# layers.2.blocks.5.mlp.fc1.weight: True
# layers.2.blocks.5.mlp.fc1.bias: True
# layers.2.blocks.5.mlp.fc2.weight: True
# layers.2.blocks.5.mlp.fc2.bias: True
# layers.2.blocks.6.norm1.weight: True
# layers.2.blocks.6.norm1.bias: True
# layers.2.blocks.6.attn.relative_position_bias_table: True
# layers.2.blocks.6.attn.qkv.weight: True
# layers.2.blocks.6.attn.qkv.bias: True
# layers.2.blocks.6.attn.proj.weight: True
# layers.2.blocks.6.attn.proj.bias: True
# layers.2.blocks.6.norm2.weight: True
# layers.2.blocks.6.norm2.bias: True
# layers.2.blocks.6.mlp.fc1.weight: True
# layers.2.blocks.6.mlp.fc1.bias: True
# layers.2.blocks.6.mlp.fc2.weight: True
# layers.2.blocks.6.mlp.fc2.bias: True
# layers.2.blocks.7.norm1.weight: True
# layers.2.blocks.7.norm1.bias: True
# layers.2.blocks.7.attn.relative_position_bias_table: True
# layers.2.blocks.7.attn.qkv.weight: True
# layers.2.blocks.7.attn.qkv.bias: True
# layers.2.blocks.7.attn.proj.weight: True
# layers.2.blocks.7.attn.proj.bias: True
# layers.2.blocks.7.norm2.weight: True
# layers.2.blocks.7.norm2.bias: True
# layers.2.blocks.7.mlp.fc1.weight: True
# layers.2.blocks.7.mlp.fc1.bias: True
# layers.2.blocks.7.mlp.fc2.weight: True
# layers.2.blocks.7.mlp.fc2.bias: True
# layers.2.blocks.8.norm1.weight: True
# layers.2.blocks.8.norm1.bias: True
# layers.2.blocks.8.attn.relative_position_bias_table: True
# layers.2.blocks.8.attn.qkv.weight: True
# layers.2.blocks.8.attn.qkv.bias: True
# layers.2.blocks.8.attn.proj.weight: True
# layers.2.blocks.8.attn.proj.bias: True
# layers.2.blocks.8.norm2.weight: True
# layers.2.blocks.8.norm2.bias: True
# layers.2.blocks.8.mlp.fc1.weight: True
# layers.2.blocks.8.mlp.fc1.bias: True
# layers.2.blocks.8.mlp.fc2.weight: True
# layers.2.blocks.8.mlp.fc2.bias: True
# layers.2.blocks.9.norm1.weight: True
# layers.2.blocks.9.norm1.bias: True
# layers.2.blocks.9.attn.relative_position_bias_table: True
# layers.2.blocks.9.attn.qkv.weight: True
# layers.2.blocks.9.attn.qkv.bias: True
# layers.2.blocks.9.attn.proj.weight: True
# layers.2.blocks.9.attn.proj.bias: True
# layers.2.blocks.9.norm2.weight: True
# layers.2.blocks.9.norm2.bias: True
# layers.2.blocks.9.mlp.fc1.weight: True
# layers.2.blocks.9.mlp.fc1.bias: True
# layers.2.blocks.9.mlp.fc2.weight: True
# layers.2.blocks.9.mlp.fc2.bias: True
# layers.2.blocks.10.norm1.weight: True
# layers.2.blocks.10.norm1.bias: True
# layers.2.blocks.10.attn.relative_position_bias_table: True
# layers.2.blocks.10.attn.qkv.weight: True
# layers.2.blocks.10.attn.qkv.bias: True
# layers.2.blocks.10.attn.proj.weight: True
# layers.2.blocks.10.attn.proj.bias: True
# layers.2.blocks.10.norm2.weight: True
# layers.2.blocks.10.norm2.bias: True
# layers.2.blocks.10.mlp.fc1.weight: True
# layers.2.blocks.10.mlp.fc1.bias: True
# layers.2.blocks.10.mlp.fc2.weight: True
# layers.2.blocks.10.mlp.fc2.bias: True
# layers.2.blocks.11.norm1.weight: True
# layers.2.blocks.11.norm1.bias: True
# layers.2.blocks.11.attn.relative_position_bias_table: True
# layers.2.blocks.11.attn.qkv.weight: True
# layers.2.blocks.11.attn.qkv.bias: True
# layers.2.blocks.11.attn.proj.weight: True
# layers.2.blocks.11.attn.proj.bias: True
# layers.2.blocks.11.norm2.weight: True
# layers.2.blocks.11.norm2.bias: True
# layers.2.blocks.11.mlp.fc1.weight: True
# layers.2.blocks.11.mlp.fc1.bias: True
# layers.2.blocks.11.mlp.fc2.weight: True
# layers.2.blocks.11.mlp.fc2.bias: True
# layers.2.blocks.12.norm1.weight: True
# layers.2.blocks.12.norm1.bias: True
# layers.2.blocks.12.attn.relative_position_bias_table: True
# layers.2.blocks.12.attn.qkv.weight: True
# layers.2.blocks.12.attn.qkv.bias: True
# layers.2.blocks.12.attn.proj.weight: True
# layers.2.blocks.12.attn.proj.bias: True
# layers.2.blocks.12.norm2.weight: True
# layers.2.blocks.12.norm2.bias: True
# layers.2.blocks.12.mlp.fc1.weight: True
# layers.2.blocks.12.mlp.fc1.bias: True
# layers.2.blocks.12.mlp.fc2.weight: True
# layers.2.blocks.12.mlp.fc2.bias: True
# layers.2.blocks.13.norm1.weight: True
# layers.2.blocks.13.norm1.bias: True
# layers.2.blocks.13.attn.relative_position_bias_table: True
# layers.2.blocks.13.attn.qkv.weight: True
# layers.2.blocks.13.attn.qkv.bias: True
# layers.2.blocks.13.attn.proj.weight: True
# layers.2.blocks.13.attn.proj.bias: True
# layers.2.blocks.13.norm2.weight: True
# layers.2.blocks.13.norm2.bias: True
# layers.2.blocks.13.mlp.fc1.weight: True
# layers.2.blocks.13.mlp.fc1.bias: True
# layers.2.blocks.13.mlp.fc2.weight: True
# layers.2.blocks.13.mlp.fc2.bias: True
# layers.2.blocks.14.norm1.weight: True
# layers.2.blocks.14.norm1.bias: True
# layers.2.blocks.14.attn.relative_position_bias_table: True
# layers.2.blocks.14.attn.qkv.weight: True
# layers.2.blocks.14.attn.qkv.bias: True
# layers.2.blocks.14.attn.proj.weight: True
# layers.2.blocks.14.attn.proj.bias: True
# layers.2.blocks.14.norm2.weight: True
# layers.2.blocks.14.norm2.bias: True
# layers.2.blocks.14.mlp.fc1.weight: True
# layers.2.blocks.14.mlp.fc1.bias: True
# layers.2.blocks.14.mlp.fc2.weight: True
# layers.2.blocks.14.mlp.fc2.bias: True
# layers.2.blocks.15.norm1.weight: True
# layers.2.blocks.15.norm1.bias: True
# layers.2.blocks.15.attn.relative_position_bias_table: True
# layers.2.blocks.15.attn.qkv.weight: True
# layers.2.blocks.15.attn.qkv.bias: True
# layers.2.blocks.15.attn.proj.weight: True
# layers.2.blocks.15.attn.proj.bias: True
# layers.2.blocks.15.norm2.weight: True
# layers.2.blocks.15.norm2.bias: True
# layers.2.blocks.15.mlp.fc1.weight: True
# layers.2.blocks.15.mlp.fc1.bias: True
# layers.2.blocks.15.mlp.fc2.weight: True
# layers.2.blocks.15.mlp.fc2.bias: True
# layers.2.blocks.16.norm1.weight: True
# layers.2.blocks.16.norm1.bias: True
# layers.2.blocks.16.attn.relative_position_bias_table: True
# layers.2.blocks.16.attn.qkv.weight: True
# layers.2.blocks.16.attn.qkv.bias: True
# layers.2.blocks.16.attn.proj.weight: True
# layers.2.blocks.16.attn.proj.bias: True
# layers.2.blocks.16.norm2.weight: True
# layers.2.blocks.16.norm2.bias: True
# layers.2.blocks.16.mlp.fc1.weight: True
# layers.2.blocks.16.mlp.fc1.bias: True
# layers.2.blocks.16.mlp.fc2.weight: True
# layers.2.blocks.16.mlp.fc2.bias: True
# layers.2.blocks.17.norm1.weight: True
# layers.2.blocks.17.norm1.bias: True
# layers.2.blocks.17.attn.relative_position_bias_table: True
# layers.2.blocks.17.attn.qkv.weight: True
# layers.2.blocks.17.attn.qkv.bias: True
# layers.2.blocks.17.attn.proj.weight: True
# layers.2.blocks.17.attn.proj.bias: True
# layers.2.blocks.17.norm2.weight: True
# layers.2.blocks.17.norm2.bias: True
# layers.2.blocks.17.mlp.fc1.weight: True
# layers.2.blocks.17.mlp.fc1.bias: True
# layers.2.blocks.17.mlp.fc2.weight: True
# layers.2.blocks.17.mlp.fc2.bias: True
# layers.3.downsample.norm.weight: True
# layers.3.downsample.norm.bias: True
# layers.3.downsample.reduction.weight: True
# layers.3.blocks.0.norm1.weight: True
# layers.3.blocks.0.norm1.bias: True
# layers.3.blocks.0.attn.relative_position_bias_table: True
# layers.3.blocks.0.attn.qkv.weight: True
# layers.3.blocks.0.attn.qkv.bias: True
# layers.3.blocks.0.attn.proj.weight: True
# layers.3.blocks.0.attn.proj.bias: True
# layers.3.blocks.0.norm2.weight: True
# layers.3.blocks.0.norm2.bias: True
# layers.3.blocks.0.mlp.fc1.weight: True
# layers.3.blocks.0.mlp.fc1.bias: True
# layers.3.blocks.0.mlp.fc2.weight: True
# layers.3.blocks.0.mlp.fc2.bias: True
# layers.3.blocks.1.norm1.weight: True
# layers.3.blocks.1.norm1.bias: True
# layers.3.blocks.1.attn.relative_position_bias_table: True
# layers.3.blocks.1.attn.qkv.weight: True
# layers.3.blocks.1.attn.qkv.bias: True
# layers.3.blocks.1.attn.proj.weight: True
# layers.3.blocks.1.attn.proj.bias: True
# layers.3.blocks.1.norm2.weight: True
# layers.3.blocks.1.norm2.bias: True
# layers.3.blocks.1.mlp.fc1.weight: True
# layers.3.blocks.1.mlp.fc1.bias: True
# layers.3.blocks.1.mlp.fc2.weight: True
# layers.3.blocks.1.mlp.fc2.bias: True
# norm.weight: True
# norm.bias: True
# head.fc.weight: True
# head.fc.bias: True

# %% [markdown]
# ### output test

# %%
mega.to(device)
test_input = torch.ones(1, 3, 384, 384)
test_input = test_input.to(device)
with torch.no_grad():
    test_output = mega(test_input)
print(test_output.shape)
# Out:
# torch.Size([1, 1024])

# %% [markdown]
# ### hyperparameters

# %%
base_lr = 8e-5

param_groups = [
    {'params': [], 'lr': base_lr * 0.0625},
    {'params': [], 'lr': base_lr * 0.125},
    {'params': [], 'lr': base_lr * 0.5},
    {'params': [], 'lr': base_lr},
]

for name, param in mega.named_parameters():
    if not param.requires_grad:
        continue
    if 'layers.2.blocks' in name:
        param_groups[0]['params'].append(param)
    elif 'layers.3' in name:
        param_groups[1]['params'].append(param)
    elif name.startswith('norm'):
        param_groups[2]['params'].append(param)
    elif name.startswith('head'):
        param_groups[3]['params'].append(param)
    else:
        pass


optimizer = optim.AdamW(param_groups, weight_decay=0.01)


for i, group in enumerate(optimizer.param_groups):
    print(f'Group {i}: lr={group["lr"]}, number of parameters={len(group["params"])}')
# Out:
# Group 0: lr=5e-06, number of parameters=234
# Group 1: lr=1e-05, number of parameters=29
# Group 2: lr=4e-05, number of parameters=2
# Group 3: lr=8e-05, number of parameters=2

# %%
distance = distances.CosineSimilarity()
reducer = reducers.ThresholdReducer(low=0)
loss_func = losses.TripletMarginLoss(margin=Vmargin, distance=distance, reducer=reducer)
mining_func = miners.TripletMarginMiner(
    margin=Vmargin, distance=distance, type_of_triplets="semihard"
)
accuracy_calculator = AccuracyCalculator(include=("precision_at_1",), k=1)
sampler = samplers.MPerClassSampler(training_labels, m=4, batch_size=batch_size, length_before_new_iter=len(training))

# %%
# scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.1, patience=2, verbose=True,min_lr=1e-6)

# %%
import pytorch_metric_learning.utils.logging_presets as LP
from pytorch_metric_learning.trainers import TrainWithClassifier
from pytorch_metric_learning.testers import GlobalEmbeddingSpaceTester
import torch
import os


log_folder = "/kaggle/working/metric_learning_logs"
tensorboard_folder = "/kaggle/working/metric_learning_tensorboard"
model_folder = "/kaggle/working/metric_learning_models"

os.makedirs(log_folder, exist_ok=True)
os.makedirs(tensorboard_folder, exist_ok=True)
os.makedirs(model_folder, exist_ok=True)


record_keeper, _, _ = LP.get_record_keeper(log_folder, tensorboard_folder)
hooks = LP.get_hook_container(record_keeper)
hooks.primary_metric = "precision_at_1"
hooks.log_freq = 1


tester = GlobalEmbeddingSpaceTester(
    dataloader_num_workers=4,
    normalize_embeddings=True,
    use_trunk_output=True,
    batch_size=batch_size,
    data_device=device,
    accuracy_calculator=accuracy_calculator,
    end_of_testing_hook=hooks.end_of_testing_hook
)


dataset_dict = {"val": test, "fromtrain": subtraining}


end_of_epoch_hook = hooks.end_of_epoch_hook(
    tester, 
    dataset_dict, 
    model_folder,
    test_interval=1,
    patience=4
)


models = {"trunk": mega}
loss_funcs = {"metric_loss": loss_func}
mining_funcs = {"tuple_miner": mining_func}
optimizers = {"trunk_optimizer": optimizer}
# lr_schedulers = {"trunk_scheduler_by_iteration": scheduler}


trainer = TrainWithClassifier(
    models=models,
    optimizers=optimizers,
    batch_size=batch_size,
    loss_funcs=loss_funcs,
    mining_funcs=mining_funcs,
    dataset=training,
    sampler=sampler,
    # lr_schedulers=lr_schedulers,
    end_of_iteration_hook=hooks.end_of_iteration_hook,
    end_of_epoch_hook=end_of_epoch_hook,
    dataloader_num_workers=4,
    data_device=torch.device("cuda" if torch.cuda.is_available() else "cpu")
)

# %%
trainer.train(num_epochs=20)
# Out:
# total_loss=0.09224: 100%|██████████| 550/550 [15:01<00:00,  1.64s/it]
# 100%|██████████| 86/86 [01:00<00:00,  1.43it/s]
# 100%|██████████| 91/91 [01:03<00:00,  1.44it/s]
# total_loss=0.10267: 100%|██████████| 550/550 [15:02<00:00,  1.64s/it]
# 100%|██████████| 86/86 [01:00<00:00,  1.43it/s]
# 100%|██████████| 91/91 [01:03<00:00,  1.44it/s]
# total_loss=0.03640: 100%|██████████| 550/550 [15:02<00:00,  1.64s/it]
# 100%|██████████| 86/86 [01:00<00:00,  1.43it/s]
# 100%|██████████| 91/91 [01:03<00:00,  1.44it/s]
# total_loss=0.07521: 100%|██████████| 550/550 [15:02<00:00,  1.64s/it]
# 100%|██████████| 86/86 [01:00<00:00,  1.43it/s]
# 100%|██████████| 91/91 [01:03<00:00,  1.44it/s]
# total_loss=0.06163: 100%|██████████| 550/550 [15:03<00:00,  1.64s/it]
# 100%|██████████| 86/86 [01:00<00:00,  1.43it/s]
# 100%|██████████| 91/91 [01:03<00:00,  1.44it/s]
# total_loss=0.00000: 100%|██████████| 550/550 [15:02<00:00,  1.64s/it]
# 100%|██████████| 86/86 [01:00<00:00,  1.43it/s]
# 100%|██████████| 91/91 [01:03<00:00,  1.44it/s]
# total_loss=0.06227: 100%|██████████| 550/550 [15:03<00:00,  1.64s/it]
# 100%|██████████| 86/86 [01:00<00:00,  1.43it/s]
# 100%|██████████| 91/91 [01:03<00:00,  1.44it/s]
# total_loss=0.08652: 100%|██████████| 550/550 [15:02<00:00,  1.64s/it]
# 100%|██████████| 86/86 [01:00<00:00,  1.43it/s]
# 100%|██████████| 91/91 [01:03<00:00,  1.43it/s]
# total_loss=0.05420: 100%|██████████| 550/550 [15:01<00:00,  1.64s/it]
# 100%|██████████| 86/86 [01:00<00:00,  1.43it/s]
# 100%|██████████| 91/91 [01:03<00:00,  1.44it/s]
# total_loss=0.00000: 100%|██████████| 550/550 [15:01<00:00,  1.64s/it]
# 100%|██████████| 86/86 [01:00<00:00,  1.43it/s]
# 100%|██████████| 91/91 [01:03<00:00,  1.44it/s]
# total_loss=0.07177: 100%|██████████| 550/550 [15:01<00:00,  1.64s/it]
# 100%|██████████| 86/86 [01:00<00:00,  1.43it/s]
# 100%|██████████| 91/91 [01:03<00:00,  1.43it/s]
# total_loss=0.11694: 100%|██████████| 550/550 [15:01<00:00,  1.64s/it]
# 100%|██████████| 86/86 [01:00<00:00,  1.43it/s]
# 100%|██████████| 91/91 [01:03<00:00,  1.44it/s]
# total_loss=0.03829: 100%|██████████| 550/550 [15:01<00:00,  1.64s/it]
# 100%|██████████| 86/86 [01:00<00:00,  1.43it/s]
# 100%|██████████| 91/91 [01:02<00:00,  1.44it/s]
# total_loss=0.02550: 100%|██████████| 550/550 [15:02<00:00,  1.64s/it]
# 100%|██████████| 86/86 [01:00<00:00,  1.43it/s]
# 100%|██████████| 91/91 [01:03<00:00,  1.44it/s]
# total_loss=0.08321: 100%|██████████| 550/550 [15:00<00:00,  1.64s/it]
# 100%|██████████| 86/86 [01:00<00:00,  1.43it/s]
# 100%|██████████| 91/91 [01:03<00:00,  1.44it/s]
# total_loss=0.02612: 100%|██████████| 550/550 [15:01<00:00,  1.64s/it]
# 100%|██████████| 86/86 [01:00<00:00,  1.42it/s]
# 100%|██████████| 91/91 [01:03<00:00,  1.44it/s]
# total_loss=0.00000: 100%|██████████| 550/550 [15:01<00:00,  1.64s/it]
# 100%|██████████| 86/86 [01:00<00:00,  1.43it/s]
# 100%|██████████| 91/91 [01:03<00:00,  1.44it/s]
# total_loss=0.00000: 100%|██████████| 550/550 [15:01<00:00,  1.64s/it]
# 100%|██████████| 86/86 [01:00<00:00,  1.43it/s]
# 100%|██████████| 91/91 [01:03<00:00,  1.44it/s]
# total_loss=0.08072: 100%|██████████| 550/550 [15:01<00:00,  1.64s/it]
# 100%|██████████| 86/86 [01:00<00:00,  1.43it/s]
# 100%|██████████| 91/91 [01:03<00:00,  1.44it/s]
# total_loss=0.05817: 100%|██████████| 550/550 [15:01<00:00,  1.64s/it]
# 100%|██████████| 86/86 [01:00<00:00,  1.43it/s]
# 100%|██████████| 91/91 [01:03<00:00,  1.44it/s]

# %%
torch.save(mega.state_dict(), '/kaggle/working/model_nn.pth')
