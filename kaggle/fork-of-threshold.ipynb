# %%
# !pip install git+https://github.com/WildlifeDatasets/wildlife-datasets@develop
# !pip install git+https://github.com/lightshing/wildlife-tools
# !pip install pytorch-metric-learning
# !pip install umap-learn
# !pip install umap
# !pip install record-keeper
# !pip install faiss-cpu
# Out:
# Collecting git+https://github.com/WildlifeDatasets/wildlife-datasets@develop
#   Cloning https://github.com/WildlifeDatasets/wildlife-datasets (to revision develop) to /tmp/pip-req-build-ubfgm1q9
#   Running command git clone --filter=blob:none --quiet https://github.com/WildlifeDatasets/wildlife-datasets /tmp/pip-req-build-ubfgm1q9
#   Running command git checkout -b develop --track origin/develop
#   Switched to a new branch 'develop'
#   Branch 'develop' set up to track remote branch 'develop' from 'origin'.
#   Resolved https://github.com/WildlifeDatasets/wildlife-datasets to commit 753d9bf64861c3e17011136b3436bf58bf02317f
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: numpy>=1.19.4 in /usr/local/lib/python3.11/dist-packages (from wildlife-datasets==1.0.6) (1.26.4)
# Requirement already satisfied: pandas>=1.1.4 in /usr/local/lib/python3.11/dist-packages (from wildlife-datasets==1.0.6) (2.2.3)
# Requirement already satisfied: tqdm>=4.62.3 in /usr/local/lib/python3.11/dist-packages (from wildlife-datasets==1.0.6) (4.67.1)
# Requirement already satisfied: opencv-python>=4.5.5.62 in /usr/local/lib/python3.11/dist-packages (from wildlife-datasets==1.0.6) (4.11.0.86)
# Requirement already satisfied: Pillow>=7.1.2 in /usr/local/lib/python3.11/dist-packages (from wildlife-datasets==1.0.6) (11.1.0)
# Requirement already satisfied: scikit-learn>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from wildlife-datasets==1.0.6) (1.2.2)
# Requirement already satisfied: matplotlib>=3.5.1 in /usr/local/lib/python3.11/dist-packages (from wildlife-datasets==1.0.6) (3.7.2)
# Requirement already satisfied: pycocotools>=2.0.1 in /usr/local/lib/python3.11/dist-packages (from wildlife-datasets==1.0.6) (2.0.8)
# Requirement already satisfied: datasets in /usr/local/lib/python3.11/dist-packages (from wildlife-datasets==1.0.6) (3.6.0)
# Requirement already satisfied: gdown in /usr/local/lib/python3.11/dist-packages (from wildlife-datasets==1.0.6) (5.2.0)
# Requirement already satisfied: kaggle in /usr/local/lib/python3.11/dist-packages (from wildlife-datasets==1.0.6) (1.7.4.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.5.1->wildlife-datasets==1.0.6) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.5.1->wildlife-datasets==1.0.6) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.5.1->wildlife-datasets==1.0.6) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.5.1->wildlife-datasets==1.0.6) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.5.1->wildlife-datasets==1.0.6) (25.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.5.1->wildlife-datasets==1.0.6) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.5.1->wildlife-datasets==1.0.6) (2.9.0.post0)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy>=1.19.4->wildlife-datasets==1.0.6) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy>=1.19.4->wildlife-datasets==1.0.6) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy>=1.19.4->wildlife-datasets==1.0.6) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy>=1.19.4->wildlife-datasets==1.0.6) (2025.1.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy>=1.19.4->wildlife-datasets==1.0.6) (2022.1.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy>=1.19.4->wildlife-datasets==1.0.6) (2.4.1)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.4->wildlife-datasets==1.0.6) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.4->wildlife-datasets==1.0.6) (2025.2)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.0.1->wildlife-datasets==1.0.6) (1.15.2)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.0.1->wildlife-datasets==1.0.6) (1.5.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.0.1->wildlife-datasets==1.0.6) (3.6.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from datasets->wildlife-datasets==1.0.6) (3.18.0)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.11/dist-packages (from datasets->wildlife-datasets==1.0.6) (19.0.1)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from datasets->wildlife-datasets==1.0.6) (0.3.8)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.11/dist-packages (from datasets->wildlife-datasets==1.0.6) (2.32.3)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.11/dist-packages (from datasets->wildlife-datasets==1.0.6) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.11/dist-packages (from datasets->wildlife-datasets==1.0.6) (0.70.16)
# Collecting fsspec<=2025.3.0,>=2023.1.0 (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets->wildlife-datasets==1.0.6)
#   Downloading fsspec-2025.3.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: huggingface-hub>=0.24.0 in /usr/local/lib/python3.11/dist-packages (from datasets->wildlife-datasets==1.0.6) (0.31.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from datasets->wildlife-datasets==1.0.6) (6.0.2)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.11/dist-packages (from gdown->wildlife-datasets==1.0.6) (4.13.3)
# Requirement already satisfied: bleach in /usr/local/lib/python3.11/dist-packages (from kaggle->wildlife-datasets==1.0.6) (6.2.0)
# Requirement already satisfied: certifi>=14.05.14 in /usr/local/lib/python3.11/dist-packages (from kaggle->wildlife-datasets==1.0.6) (2025.4.26)
# Requirement already satisfied: charset-normalizer in /usr/local/lib/python3.11/dist-packages (from kaggle->wildlife-datasets==1.0.6) (3.4.2)
# Requirement already satisfied: idna in /usr/local/lib/python3.11/dist-packages (from kaggle->wildlife-datasets==1.0.6) (3.10)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.11/dist-packages (from kaggle->wildlife-datasets==1.0.6) (3.20.3)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.11/dist-packages (from kaggle->wildlife-datasets==1.0.6) (8.0.4)
# Requirement already satisfied: setuptools>=21.0.0 in /usr/local/lib/python3.11/dist-packages (from kaggle->wildlife-datasets==1.0.6) (75.2.0)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.11/dist-packages (from kaggle->wildlife-datasets==1.0.6) (1.17.0)
# Requirement already satisfied: text-unidecode in /usr/local/lib/python3.11/dist-packages (from kaggle->wildlife-datasets==1.0.6) (1.3)
# Requirement already satisfied: urllib3>=1.15.1 in /usr/local/lib/python3.11/dist-packages (from kaggle->wildlife-datasets==1.0.6) (2.4.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.11/dist-packages (from kaggle->wildlife-datasets==1.0.6) (0.5.1)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets->wildlife-datasets==1.0.6) (3.11.18)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.24.0->datasets->wildlife-datasets==1.0.6) (4.13.2)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.24.0->datasets->wildlife-datasets==1.0.6) (1.1.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4->gdown->wildlife-datasets==1.0.6) (2.6)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.19.4->wildlife-datasets==1.0.6) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.19.4->wildlife-datasets==1.0.6) (2022.1.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy>=1.19.4->wildlife-datasets==1.0.6) (1.3.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy>=1.19.4->wildlife-datasets==1.0.6) (2024.2.0)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown->wildlife-datasets==1.0.6) (1.7.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets->wildlife-datasets==1.0.6) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets->wildlife-datasets==1.0.6) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets->wildlife-datasets==1.0.6) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets->wildlife-datasets==1.0.6) (1.6.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets->wildlife-datasets==1.0.6) (6.4.3)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets->wildlife-datasets==1.0.6) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets->wildlife-datasets==1.0.6) (1.20.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy>=1.19.4->wildlife-datasets==1.0.6) (2024.2.0)
# Downloading fsspec-2025.3.0-py3-none-any.whl (193 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.6/193.6 kB 4.3 MB/s eta 0:00:00
# Building wheels for collected packages: wildlife-datasets
#   Building wheel for wildlife-datasets (pyproject.toml) ... done
#   Created wheel for wildlife-datasets: filename=wildlife_datasets-1.0.6-py3-none-any.whl size=88077 sha256=9fe937921cd1b82d6ce72b689344765cbaf6ba02ce2e8b691a3549eb466680a0
#   Stored in directory: /tmp/pip-ephem-wheel-cache-yemm22hv/wheels/a4/1c/dc/1ccc716ee392f8631bc5e29e97043e86bfc03b2c8da41260ee
# Successfully built wildlife-datasets
# Installing collected packages: fsspec, wildlife-datasets
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2025.3.2
#     Uninstalling fsspec-2025.3.2:
#       Successfully uninstalled fsspec-2025.3.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# cesium 0.12.4 requires numpy<3.0,>=2.0, but you have numpy 1.26.4 which is incompatible.
# bigframes 1.42.0 requires rich<14,>=12.4.4, but you have rich 14.0.0 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cublas-cu12==12.4.5.8; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cublas-cu12 12.9.0.13 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cudnn-cu12==9.1.0.70; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cudnn-cu12 9.3.0.75 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cufft-cu12==11.2.1.3; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cufft-cu12 11.4.0.6 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-curand-cu12==10.3.5.147; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-curand-cu12 10.3.10.19 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cusolver-cu12==11.6.1.9; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cusolver-cu12 11.7.4.40 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cusparse-cu12==12.3.1.170; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cusparse-cu12 12.5.9.5 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-nvjitlink-cu12==12.4.127; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-nvjitlink-cu12 12.9.41 which is incompatible.
# gcsfs 2025.3.2 requires fsspec==2025.3.2, but you have fsspec 2025.3.0 which is incompatible.
# Successfully installed fsspec-2025.3.0 wildlife-datasets-1.0.6
# Collecting git+https://github.com/lightshing/wildlife-tools
#   Cloning https://github.com/lightshing/wildlife-tools to /tmp/pip-req-build-zpgdm9x4
#   Running command git clone --filter=blob:none --quiet https://github.com/lightshing/wildlife-tools /tmp/pip-req-build-zpgdm9x4
#   Resolved https://github.com/lightshing/wildlife-tools to commit ae4163736752b389a7c0eb32da459d0611b5062d
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting gluefactory@ git+https://github.com/cvg/glue-factory.git@1f56839db2242929960d70f85bfac6c19ef2821c (from wildlife-tools==1.0.1)
#   Cloning https://github.com/cvg/glue-factory.git (to revision 1f56839db2242929960d70f85bfac6c19ef2821c) to /tmp/pip-install-gw23bhv_/gluefactory_8ba1cfbc8e414f61bce29b718b2e0e9b
#   Running command git clone --filter=blob:none --quiet https://github.com/cvg/glue-factory.git /tmp/pip-install-gw23bhv_/gluefactory_8ba1cfbc8e414f61bce29b718b2e0e9b
#   Running command git rev-parse -q --verify 'sha^1f56839db2242929960d70f85bfac6c19ef2821c'
#   Running command git fetch -q https://github.com/cvg/glue-factory.git 1f56839db2242929960d70f85bfac6c19ef2821c
#   Resolved https://github.com/cvg/glue-factory.git to commit 1f56839db2242929960d70f85bfac6c19ef2821c
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: torch>=2.0.1 in /usr/local/lib/python3.11/dist-packages (from wildlife-tools==1.0.1) (2.6.0+cu124)
# Requirement already satisfied: timm>=0.9.2 in /usr/local/lib/python3.11/dist-packages (from wildlife-tools==1.0.1) (1.0.15)
# Requirement already satisfied: numpy>=1.19.4 in /usr/local/lib/python3.11/dist-packages (from wildlife-tools==1.0.1) (1.26.4)
# Requirement already satisfied: pandas>=1.1.4 in /usr/local/lib/python3.11/dist-packages (from wildlife-tools==1.0.1) (2.2.3)
# Requirement already satisfied: tqdm>=4.62.3 in /usr/local/lib/python3.11/dist-packages (from wildlife-tools==1.0.1) (4.67.1)
# Requirement already satisfied: opencv-python>=4.5.5.62 in /usr/local/lib/python3.11/dist-packages (from wildlife-tools==1.0.1) (4.11.0.86)
# Requirement already satisfied: Pillow>=7.1.2 in /usr/local/lib/python3.11/dist-packages (from wildlife-tools==1.0.1) (11.1.0)
# Requirement already satisfied: scikit-learn>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from wildlife-tools==1.0.1) (1.2.2)
# Requirement already satisfied: pycocotools in /usr/local/lib/python3.11/dist-packages (from wildlife-tools==1.0.1) (2.0.8)
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.11/dist-packages (from wildlife-tools==1.0.1) (2.18.0)
# Collecting pytorch_metric_learning (from wildlife-tools==1.0.1)
#   Downloading pytorch_metric_learning-2.8.1-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: transformers>=4.30.2 in /usr/local/lib/python3.11/dist-packages (from wildlife-tools==1.0.1) (4.51.3)
# Requirement already satisfied: wildlife-datasets>=0.3.4 in /usr/local/lib/python3.11/dist-packages (from wildlife-tools==1.0.1) (1.0.6)
# Requirement already satisfied: kornia>=0.6.12 in /usr/local/lib/python3.11/dist-packages (from wildlife-tools==1.0.1) (0.8.1)
# Requirement already satisfied: kornia_rs>=0.1.9 in /usr/local/lib/python3.11/dist-packages (from kornia>=0.6.12->wildlife-tools==1.0.1) (0.1.9)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from kornia>=0.6.12->wildlife-tools==1.0.1) (25.0)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy>=1.19.4->wildlife-tools==1.0.1) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy>=1.19.4->wildlife-tools==1.0.1) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy>=1.19.4->wildlife-tools==1.0.1) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy>=1.19.4->wildlife-tools==1.0.1) (2025.1.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy>=1.19.4->wildlife-tools==1.0.1) (2022.1.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy>=1.19.4->wildlife-tools==1.0.1) (2.4.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.4->wildlife-tools==1.0.1) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.4->wildlife-tools==1.0.1) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.4->wildlife-tools==1.0.1) (2025.2)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.0.1->wildlife-tools==1.0.1) (1.15.2)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.0.1->wildlife-tools==1.0.1) (1.5.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.0.1->wildlife-tools==1.0.1) (3.6.0)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.11/dist-packages (from timm>=0.9.2->wildlife-tools==1.0.1) (0.21.0+cu124)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.11/dist-packages (from timm>=0.9.2->wildlife-tools==1.0.1) (6.0.2)
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.11/dist-packages (from timm>=0.9.2->wildlife-tools==1.0.1) (0.31.1)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.11/dist-packages (from timm>=0.9.2->wildlife-tools==1.0.1) (0.5.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.1->wildlife-tools==1.0.1) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.1->wildlife-tools==1.0.1) (4.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.1->wildlife-tools==1.0.1) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.1->wildlife-tools==1.0.1) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.1->wildlife-tools==1.0.1) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.1->wildlife-tools==1.0.1) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.1->wildlife-tools==1.0.1) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.1->wildlife-tools==1.0.1) (12.4.127)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=2.0.1->wildlife-tools==1.0.1)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch>=2.0.1->wildlife-tools==1.0.1)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch>=2.0.1->wildlife-tools==1.0.1)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch>=2.0.1->wildlife-tools==1.0.1)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch>=2.0.1->wildlife-tools==1.0.1)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch>=2.0.1->wildlife-tools==1.0.1)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.1->wildlife-tools==1.0.1) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.1->wildlife-tools==1.0.1) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.1->wildlife-tools==1.0.1) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch>=2.0.1->wildlife-tools==1.0.1)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.1->wildlife-tools==1.0.1) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.1->wildlife-tools==1.0.1) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=2.0.1->wildlife-tools==1.0.1) (1.3.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers>=4.30.2->wildlife-tools==1.0.1) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from transformers>=4.30.2->wildlife-tools==1.0.1) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers>=4.30.2->wildlife-tools==1.0.1) (0.21.1)
# Requirement already satisfied: matplotlib>=3.5.1 in /usr/local/lib/python3.11/dist-packages (from wildlife-datasets>=0.3.4->wildlife-tools==1.0.1) (3.7.2)
# Requirement already satisfied: datasets in /usr/local/lib/python3.11/dist-packages (from wildlife-datasets>=0.3.4->wildlife-tools==1.0.1) (3.6.0)
# Requirement already satisfied: gdown in /usr/local/lib/python3.11/dist-packages (from wildlife-datasets>=0.3.4->wildlife-tools==1.0.1) (5.2.0)
# Requirement already satisfied: kaggle in /usr/local/lib/python3.11/dist-packages (from wildlife-datasets>=0.3.4->wildlife-tools==1.0.1) (1.7.4.2)
# Collecting lightglue@ git+https://github.com/cvg/LightGlue.git (from gluefactory@ git+https://github.com/cvg/glue-factory.git@1f56839db2242929960d70f85bfac6c19ef2821c->wildlife-tools==1.0.1)
#   Cloning https://github.com/cvg/LightGlue.git to /tmp/pip-install-gw23bhv_/lightglue_de954358ddf3466a80362afdb19df57f
#   Running command git clone --filter=blob:none --quiet https://github.com/cvg/LightGlue.git /tmp/pip-install-gw23bhv_/lightglue_de954358ddf3466a80362afdb19df57f
#   Resolved https://github.com/cvg/LightGlue.git to commit edb2b838efb2ecfe3f88097c5fad9887d95aedad
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: h5py in /usr/local/lib/python3.11/dist-packages (from gluefactory@ git+https://github.com/cvg/glue-factory.git@1f56839db2242929960d70f85bfac6c19ef2821c->wildlife-tools==1.0.1) (3.13.0)
# Requirement already satisfied: omegaconf in /usr/local/lib/python3.11/dist-packages (from gluefactory@ git+https://github.com/cvg/glue-factory.git@1f56839db2242929960d70f85bfac6c19ef2821c->wildlife-tools==1.0.1) (2.3.0)
# Requirement already satisfied: albumentations in /usr/local/lib/python3.11/dist-packages (from gluefactory@ git+https://github.com/cvg/glue-factory.git@1f56839db2242929960d70f85bfac6c19ef2821c->wildlife-tools==1.0.1) (2.0.5)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.11/dist-packages (from gluefactory@ git+https://github.com/cvg/glue-factory.git@1f56839db2242929960d70f85bfac6c19ef2821c->wildlife-tools==1.0.1) (0.12.2)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.11/dist-packages (from tensorboard->wildlife-tools==1.0.1) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.11/dist-packages (from tensorboard->wildlife-tools==1.0.1) (1.72.0rc1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard->wildlife-tools==1.0.1) (3.7)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in /usr/local/lib/python3.11/dist-packages (from tensorboard->wildlife-tools==1.0.1) (3.20.3)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard->wildlife-tools==1.0.1) (75.2.0)
# Requirement already satisfied: six>1.9 in /usr/local/lib/python3.11/dist-packages (from tensorboard->wildlife-tools==1.0.1) (1.17.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard->wildlife-tools==1.0.1) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard->wildlife-tools==1.0.1) (3.1.3)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from huggingface_hub->timm>=0.9.2->wildlife-tools==1.0.1) (1.1.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.5.1->wildlife-datasets>=0.3.4->wildlife-tools==1.0.1) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.5.1->wildlife-datasets>=0.3.4->wildlife-tools==1.0.1) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.5.1->wildlife-datasets>=0.3.4->wildlife-tools==1.0.1) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.5.1->wildlife-datasets>=0.3.4->wildlife-tools==1.0.1) (1.4.8)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.5.1->wildlife-datasets>=0.3.4->wildlife-tools==1.0.1) (3.0.9)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from werkzeug>=1.0.1->tensorboard->wildlife-tools==1.0.1) (3.0.2)
# Requirement already satisfied: pydantic>=2.9.2 in /usr/local/lib/python3.11/dist-packages (from albumentations->gluefactory@ git+https://github.com/cvg/glue-factory.git@1f56839db2242929960d70f85bfac6c19ef2821c->wildlife-tools==1.0.1) (2.11.4)
# Requirement already satisfied: albucore==0.0.23 in /usr/local/lib/python3.11/dist-packages (from albumentations->gluefactory@ git+https://github.com/cvg/glue-factory.git@1f56839db2242929960d70f85bfac6c19ef2821c->wildlife-tools==1.0.1) (0.0.23)
# Requirement already satisfied: opencv-python-headless>=4.9.0.80 in /usr/local/lib/python3.11/dist-packages (from albumentations->gluefactory@ git+https://github.com/cvg/glue-factory.git@1f56839db2242929960d70f85bfac6c19ef2821c->wildlife-tools==1.0.1) (4.11.0.86)
# Requirement already satisfied: stringzilla>=3.10.4 in /usr/local/lib/python3.11/dist-packages (from albucore==0.0.23->albumentations->gluefactory@ git+https://github.com/cvg/glue-factory.git@1f56839db2242929960d70f85bfac6c19ef2821c->wildlife-tools==1.0.1) (3.12.3)
# Requirement already satisfied: simsimd>=5.9.2 in /usr/local/lib/python3.11/dist-packages (from albucore==0.0.23->albumentations->gluefactory@ git+https://github.com/cvg/glue-factory.git@1f56839db2242929960d70f85bfac6c19ef2821c->wildlife-tools==1.0.1) (6.2.1)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.11/dist-packages (from datasets->wildlife-datasets>=0.3.4->wildlife-tools==1.0.1) (19.0.1)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from datasets->wildlife-datasets>=0.3.4->wildlife-tools==1.0.1) (0.3.8)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.11/dist-packages (from datasets->wildlife-datasets>=0.3.4->wildlife-tools==1.0.1) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.11/dist-packages (from datasets->wildlife-datasets>=0.3.4->wildlife-tools==1.0.1) (0.70.16)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->transformers>=4.30.2->wildlife-tools==1.0.1) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->transformers>=4.30.2->wildlife-tools==1.0.1) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->transformers>=4.30.2->wildlife-tools==1.0.1) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->transformers>=4.30.2->wildlife-tools==1.0.1) (2025.4.26)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.11/dist-packages (from gdown->wildlife-datasets>=0.3.4->wildlife-tools==1.0.1) (4.13.3)
# Requirement already satisfied: bleach in /usr/local/lib/python3.11/dist-packages (from kaggle->wildlife-datasets>=0.3.4->wildlife-tools==1.0.1) (6.2.0)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.11/dist-packages (from kaggle->wildlife-datasets>=0.3.4->wildlife-tools==1.0.1) (8.0.4)
# Requirement already satisfied: text-unidecode in /usr/local/lib/python3.11/dist-packages (from kaggle->wildlife-datasets>=0.3.4->wildlife-tools==1.0.1) (1.3)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.11/dist-packages (from kaggle->wildlife-datasets>=0.3.4->wildlife-tools==1.0.1) (0.5.1)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.19.4->wildlife-tools==1.0.1) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.19.4->wildlife-tools==1.0.1) (2022.1.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy>=1.19.4->wildlife-tools==1.0.1) (1.3.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy>=1.19.4->wildlife-tools==1.0.1) (2024.2.0)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /usr/local/lib/python3.11/dist-packages (from omegaconf->gluefactory@ git+https://github.com/cvg/glue-factory.git@1f56839db2242929960d70f85bfac6c19ef2821c->wildlife-tools==1.0.1) (4.9.3)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets->wildlife-datasets>=0.3.4->wildlife-tools==1.0.1) (3.11.18)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy>=1.19.4->wildlife-tools==1.0.1) (2024.2.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.9.2->albumentations->gluefactory@ git+https://github.com/cvg/glue-factory.git@1f56839db2242929960d70f85bfac6c19ef2821c->wildlife-tools==1.0.1) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.9.2->albumentations->gluefactory@ git+https://github.com/cvg/glue-factory.git@1f56839db2242929960d70f85bfac6c19ef2821c->wildlife-tools==1.0.1) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.9.2->albumentations->gluefactory@ git+https://github.com/cvg/glue-factory.git@1f56839db2242929960d70f85bfac6c19ef2821c->wildlife-tools==1.0.1) (0.4.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4->gdown->wildlife-datasets>=0.3.4->wildlife-tools==1.0.1) (2.6)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown->wildlife-datasets>=0.3.4->wildlife-tools==1.0.1) (1.7.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets->wildlife-datasets>=0.3.4->wildlife-tools==1.0.1) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets->wildlife-datasets>=0.3.4->wildlife-tools==1.0.1) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets->wildlife-datasets>=0.3.4->wildlife-tools==1.0.1) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets->wildlife-datasets>=0.3.4->wildlife-tools==1.0.1) (1.6.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets->wildlife-datasets>=0.3.4->wildlife-tools==1.0.1) (6.4.3)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets->wildlife-datasets>=0.3.4->wildlife-tools==1.0.1) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets->wildlife-datasets>=0.3.4->wildlife-tools==1.0.1) (1.20.0)
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.5 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.4 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.9 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 14.4 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 12.7 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 7.8 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 69.6 MB/s eta 0:00:00
# Downloading pytorch_metric_learning-2.8.1-py3-none-any.whl (125 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 125.9/125.9 kB 6.5 MB/s eta 0:00:00
# Building wheels for collected packages: wildlife-tools, gluefactory, lightglue
#   Building wheel for wildlife-tools (pyproject.toml) ... done
#   Created wheel for wildlife-tools: filename=wildlife_tools-1.0.1-py3-none-any.whl size=34272 sha256=97fe085c914fea4a260a16f1a5a10f5bda88ccbf5332b4f35f155ccded91d890
#   Stored in directory: /tmp/pip-ephem-wheel-cache-g4sdombi/wheels/41/2b/82/5299a66e1a47adae93d7e59df736717b60ba1694af62c92db2
#   Building wheel for gluefactory (pyproject.toml) ... done
#   Created wheel for gluefactory: filename=gluefactory-0.0-py3-none-any.whl size=213006 sha256=fcbf1472be086368a640dc95afa916a0a55ab4fb945bdad22712d190336e9d18
#   Stored in directory: /root/.cache/pip/wheels/66/e5/65/9ef7f587d744224ea98adb58aeb958952f54dcbc95378afb23
#   Building wheel for lightglue (pyproject.toml) ... done
#   Created wheel for lightglue: filename=lightglue-0.0-py3-none-any.whl size=39544 sha256=ef35c9a65b9cd89ba0a5fe76986cdb5eb6399b1fd843a4bd342c0882858a56f5
#   Stored in directory: /tmp/pip-ephem-wheel-cache-g4sdombi/wheels/5f/e0/67/3e514ef8c284be99a185335241d29522d5fd476f4a69f01f07
# Successfully built wildlife-tools gluefactory lightglue
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, lightglue, pytorch_metric_learning, gluefactory, wildlife-tools
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.9.41
#     Uninstalling nvidia-nvjitlink-cu12-12.9.41:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.9.41
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.10.19
#     Uninstalling nvidia-curand-cu12-10.3.10.19:
#       Successfully uninstalled nvidia-curand-cu12-10.3.10.19
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.4.0.6
#     Uninstalling nvidia-cufft-cu12-11.4.0.6:
#       Successfully uninstalled nvidia-cufft-cu12-11.4.0.6
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.9.0.13
#     Uninstalling nvidia-cublas-cu12-12.9.0.13:
#       Successfully uninstalled nvidia-cublas-cu12-12.9.0.13
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.9.5
#     Uninstalling nvidia-cusparse-cu12-12.5.9.5:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.9.5
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.7.4.40
#     Uninstalling nvidia-cusolver-cu12-11.7.4.40:
#       Successfully uninstalled nvidia-cusolver-cu12-11.7.4.40
# Successfully installed gluefactory-0.0 lightglue-0.0 nvidia-cublas-cu12-12.4.5.8 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 pytorch_metric_learning-2.8.1 wildlife-tools-1.0.1
# Requirement already satisfied: pytorch-metric-learning in /usr/local/lib/python3.11/dist-packages (2.8.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from pytorch-metric-learning) (1.26.4)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (from pytorch-metric-learning) (1.2.2)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from pytorch-metric-learning) (2.6.0+cu124)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from pytorch-metric-learning) (4.67.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=1.6.0->pytorch-metric-learning) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.6.0->pytorch-metric-learning) (4.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.6.0->pytorch-metric-learning) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.6.0->pytorch-metric-learning) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=1.6.0->pytorch-metric-learning) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.6.0->pytorch-metric-learning) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.6.0->pytorch-metric-learning) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.6.0->pytorch-metric-learning) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=1.6.0->pytorch-metric-learning) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch>=1.6.0->pytorch-metric-learning) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch>=1.6.0->pytorch-metric-learning) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch>=1.6.0->pytorch-metric-learning) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch>=1.6.0->pytorch-metric-learning) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch>=1.6.0->pytorch-metric-learning) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.6.0->pytorch-metric-learning) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.6.0->pytorch-metric-learning) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.6.0->pytorch-metric-learning) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.6.0->pytorch-metric-learning) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.6.0->pytorch-metric-learning) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.6.0->pytorch-metric-learning) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.6.0->pytorch-metric-learning) (1.3.0)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy->pytorch-metric-learning) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy->pytorch-metric-learning) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy->pytorch-metric-learning) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy->pytorch-metric-learning) (2025.1.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy->pytorch-metric-learning) (2022.1.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy->pytorch-metric-learning) (2.4.1)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->pytorch-metric-learning) (1.15.2)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->pytorch-metric-learning) (1.5.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->pytorch-metric-learning) (3.6.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.6.0->pytorch-metric-learning) (3.0.2)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->pytorch-metric-learning) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->pytorch-metric-learning) (2022.1.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy->pytorch-metric-learning) (1.3.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy->pytorch-metric-learning) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy->pytorch-metric-learning) (2024.2.0)
# Requirement already satisfied: umap-learn in /usr/local/lib/python3.11/dist-packages (0.5.7)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from umap-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from umap-learn) (1.15.2)
# Requirement already satisfied: scikit-learn>=0.22 in /usr/local/lib/python3.11/dist-packages (from umap-learn) (1.2.2)
# Requirement already satisfied: numba>=0.51.2 in /usr/local/lib/python3.11/dist-packages (from umap-learn) (0.60.0)
# Requirement already satisfied: pynndescent>=0.5 in /usr/local/lib/python3.11/dist-packages (from umap-learn) (0.5.13)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from umap-learn) (4.67.1)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.11/dist-packages (from numba>=0.51.2->umap-learn) (0.43.0)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy>=1.17->umap-learn) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy>=1.17->umap-learn) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy>=1.17->umap-learn) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy>=1.17->umap-learn) (2025.1.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy>=1.17->umap-learn) (2022.1.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy>=1.17->umap-learn) (2.4.1)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.11/dist-packages (from pynndescent>=0.5->umap-learn) (1.5.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=0.22->umap-learn) (3.6.0)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.17->umap-learn) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.17->umap-learn) (2022.1.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy>=1.17->umap-learn) (1.3.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy>=1.17->umap-learn) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy>=1.17->umap-learn) (2024.2.0)
# Collecting umap
#   Downloading umap-0.1.1.tar.gz (3.2 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: umap
#   Building wheel for umap (setup.py) ... done
#   Created wheel for umap: filename=umap-0.1.1-py3-none-any.whl size=3541 sha256=4a33f642fdc1e49ce6330486d34ac11cd320bfea303c37142bb07506b57b8e8f
#   Stored in directory: /root/.cache/pip/wheels/82/d8/73/e9eb3334baaad795ff0278363ff1aca7568bdf2793e452a527
# Successfully built umap
# Installing collected packages: umap
# Successfully installed umap-0.1.1
# Collecting record-keeper
#   Downloading record_keeper-0.9.32-py3-none-any.whl.metadata (3.1 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from record-keeper) (1.26.4)
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (from record-keeper) (2.6.0+cu124)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy->record-keeper) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy->record-keeper) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy->record-keeper) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy->record-keeper) (2025.1.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy->record-keeper) (2022.1.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy->record-keeper) (2.4.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch->record-keeper) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch->record-keeper) (4.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch->record-keeper) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch->record-keeper) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch->record-keeper) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->record-keeper) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->record-keeper) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->record-keeper) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch->record-keeper) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch->record-keeper) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch->record-keeper) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch->record-keeper) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch->record-keeper) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch->record-keeper) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch->record-keeper) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch->record-keeper) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->record-keeper) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->record-keeper) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch->record-keeper) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch->record-keeper) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch->record-keeper) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch->record-keeper) (3.0.2)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->record-keeper) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->record-keeper) (2022.1.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy->record-keeper) (1.3.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy->record-keeper) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy->record-keeper) (2024.2.0)
# Downloading record_keeper-0.9.32-py3-none-any.whl (8.2 kB)
# Installing collected packages: record-keeper
# Successfully installed record-keeper-0.9.32
# Collecting faiss-cpu
#   Downloading faiss_cpu-1.11.0-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (4.8 kB)
# Requirement already satisfied: numpy<3.0,>=1.25.0 in /usr/local/lib/python3.11/dist-packages (from faiss-cpu) (1.26.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from faiss-cpu) (25.0)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy<3.0,>=1.25.0->faiss-cpu) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy<3.0,>=1.25.0->faiss-cpu) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy<3.0,>=1.25.0->faiss-cpu) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy<3.0,>=1.25.0->faiss-cpu) (2025.1.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy<3.0,>=1.25.0->faiss-cpu) (2022.1.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy<3.0,>=1.25.0->faiss-cpu) (2.4.1)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy<3.0,>=1.25.0->faiss-cpu) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy<3.0,>=1.25.0->faiss-cpu) (2022.1.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy<3.0,>=1.25.0->faiss-cpu) (1.3.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy<3.0,>=1.25.0->faiss-cpu) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy<3.0,>=1.25.0->faiss-cpu) (2024.2.0)
# Downloading faiss_cpu-1.11.0-cp311-cp311-manylinux_2_28_x86_64.whl (31.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 31.3/31.3 MB 53.5 MB/s eta 0:00:00
# Installing collected packages: faiss-cpu
# Successfully installed faiss-cpu-1.11.0

# %%
import os
import numpy as np
import pandas as pd
import timm
import torchvision.transforms as T
import torch
from torch import nn
from torch import optim
from torch.utils.tensorboard import SummaryWriter
from datetime import datetime
from wildlife_datasets.datasets import AnimalCLEF2025
from wildlife_datasets import splits
from sklearn.preprocessing import LabelEncoder

# %matplotlib inline
import logging



from pytorch_metric_learning import distances, reducers

import pytorch_metric_learning
from pytorch_metric_learning import losses, miners, samplers
from pytorch_metric_learning.utils.accuracy_calculator import AccuracyCalculator
import pytorch_metric_learning.utils.logging_presets as LP
from pytorch_metric_learning.trainers import TrainWithClassifier
from pytorch_metric_learning.testers import BaseTester
import torch
import os
from wildlife_tools.features import DeepFeatures
from wildlife_tools.similarity import CosineSimilarity


logging.getLogger().setLevel(logging.INFO)
logging.info("VERSION %s" % pytorch_metric_learning.__version__)
# Out:
# 2025-05-15 20:18:34.840815: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1747340315.046355      19 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1747340315.102024      19 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
import numpy as np
from typing import List, Union
import os
import numpy as np
import pandas as pd
import timm
import torchvision.transforms as T
import torch
from torch.utils.data import Dataset, DataLoader
import torch.nn as nn
import torch.optim as optim
import numpy as np
from tqdm import tqdm
from wildlife_datasets.datasets import AnimalCLEF2025
from wildlife_tools.features import DeepFeatures
from wildlife_tools.similarity import CosineSimilarity

def baks_compute(
        y_true: Union[List, np.ndarray],
        y_pred: Union[List, np.ndarray],
        identity_test_only: Union[List, np.ndarray]
    ) -> float:
    """Computes BAKS (balanced accuracy on known samples).
    
    Focuses only on samples with known identities (not in identity_test_only).
    
    Args:
        y_true: True labels
        y_pred: Predicted labels
        identity_test_only: Labels of unknown identities (only in test set)
        
    Returns:
        Balanced accuracy score for known samples
    """
    # Convert inputs to numpy arrays with object dtype to handle mixed types
    y_true = np.array(y_true, dtype=object)
    y_pred = np.array(y_pred, dtype=object)
    identity_test_only = np.array(identity_test_only, dtype=object)
    
    # Filter out unknown samples
    mask = ~np.isin(y_true, identity_test_only)
    y_true_known = y_true[mask]
    y_pred_known = y_pred[mask]
    
    if len(y_true_known) == 0:
        return 0.0
    
    # Get unique classes in the filtered true labels
    unique_classes = np.unique(y_true_known)
    n_classes = len(unique_classes)
    
    # Compute per-class accuracy and average
    class_accuracies = []
    for cls in unique_classes:
        cls_mask = (y_true_known == cls)
        if np.sum(cls_mask) > 0:
            cls_acc = np.mean(y_pred_known[cls_mask] == cls)
            class_accuracies.append(cls_acc)
    
    # Return the balanced accuracy (mean of per-class accuracies)
    return np.mean(class_accuracies) if class_accuracies else 0.0

def baus_compute(
        y_true: Union[List, np.ndarray],
        y_pred: Union[List, np.ndarray],
        identity_test_only: Union[List, np.ndarray],
        new_class: Union[int, str]
    ) -> float:
    """Computes BAUS (balanced accuracy on unknown samples).
    
    Focuses only on samples with unknown identities (in identity_test_only).
    
    Args:
        y_true: True labels
        y_pred: Predicted labels
        identity_test_only: Labels of unknown identities (only in test set)
        new_class: Label used for identifying unknown samples
        
    Returns:
        Balanced accuracy score for unknown samples
    """
    # Convert inputs to numpy arrays with object dtype to handle mixed types
    y_true = np.array(y_true, dtype=object)
    y_pred = np.array(y_pred, dtype=object)
    identity_test_only = np.array(identity_test_only, dtype=object)
    
    # Filter to include only unknown samples
    mask = np.isin(y_true, identity_test_only)
    y_true_unknown = y_true[mask]
    y_pred_unknown = y_pred[mask]
    
    if len(y_true_unknown) == 0:
        return 0.0
    
    # Get unique unknown classes
    unique_unknown_classes = np.unique(y_true_unknown)
    
    # For each unknown class, check if they were correctly predicted as new_class
    class_accuracies = []
    for cls in unique_unknown_classes:
        cls_mask = (y_true_unknown == cls)
        if np.sum(cls_mask) > 0:
            # For unknown samples, correct prediction is new_class
            cls_acc = np.mean(y_pred_unknown[cls_mask] == new_class)
            class_accuracies.append(cls_acc)
    
    # Return the balanced accuracy (mean of per-class accuracies)
    return np.mean(class_accuracies) if class_accuracies else 0.0


def compute_geometric_mean(baks, baus):
    return np.sqrt(baks * baus)


def create_sample_submission(dataset_query, predictions, file_name='sample_submission.csv'):
    df = pd.DataFrame({
        'image_id': dataset_query.metadata['image_id'],
        'identity': predictions
    })
    df.to_csv(file_name, index=False)
    
root = '/kaggle/input/animal-clef-2025'
import cv2
import numpy as np
from PIL import Image
class GammaCorrection(object):
    """
    Gamma校正增强的Transform实现
    """
    def __init__(self, gamma=1.0):
        self.gamma = gamma
        self.inv_gamma = 1.0 / gamma
        self.table = np.array([((i / 255.0) ** self.inv_gamma) * 255
                             for i in np.arange(0, 256)]).astype("uint8")
    
    def __call__(self, img):
        # 将PIL图像转换为numpy数组
        img_np = np.array(img)
        # 应用gamma校正
        img_corrected = cv2.LUT(img_np, self.table)
        # 转回PIL图像
        return Image.fromarray(img_corrected)

# 修改transform
transform = T.Compose([
    T.Resize([384, 384]),
    #CLAHE(clip_limit=2.0, tile_grid_size=(8,8)),  # 添加CLAHE
    GammaCorrection(gamma=0.5),  # 添加Gamma校正
    #ImgAugTransform(),
    T.ToTensor(),
    T.Normalize(mean=(0.485, 0.456, 0.406), std=(0.229, 0.224, 0.225))
])

# 对于display transform，我们也可以添加这些增强
transform_display = T.Compose([
    T.Resize([384, 384]),
    #CLAHE(clip_limit=2.0, tile_grid_size=(8,8)),
    GammaCorrection(gamma=0.5),
    #ImgAugTransform()
])

# %%
root = '/kaggle/input/animal-clef-2025'
out_root = '/kaggle/working'
checkpoint_out_path = '/kaggle/working/model_checkpoints'

# %%
set_split_seed = 369
training_seed = 666
batch_size = 64
Vmargin = 0.2

# %%
name = 'hf-hub:BVRA/MegaDescriptor-L-384'
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
mega = timm.create_model(name, num_classes=0, pretrained=True)
print(device)
mega = mega.to(device)
# Out:
# config.json:   0%|          | 0.00/609 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/1.94G [00:00<?, ?B/s]
# cuda

# %%
transform_mega_ori = timm.data.create_transform(
    **timm.data.resolve_data_config(mega.pretrained_cfg)
)
transform_mega_ori
# Out:
# Compose(
#     Resize(size=426, interpolation=bicubic, max_size=None, antialias=True)
#     CenterCrop(size=(384, 384))
#     MaybeToTensor()
#     Normalize(mean=tensor([0.4850, 0.4560, 0.4060]), std=tensor([0.2290, 0.2240, 0.2250]))
# )

# %%
transform = T.Compose([
    T.ToTensor(),
    *transform_mega_ori.transforms
    ])

# %% [markdown]
# ### 模型预处理

# %%
# mega.head.drop = nn.Dropout(p=0.33)
# mega.head.fc = nn.Linear(1536, 1102)

# %%
# state_dict = torch.load("/kaggle/input/notebookbf2dbdd12f/model_checkpoints/best_model.pth", weights_only=False)
# mega.load_state_dict(state_dict['model_state_dict'])

# %%
# mega.load_state_dict(torch.load("/kaggle/input/notebookbf2dbdd12f/model_checkpoints/best_model.pth"), weights_only=False)

# %%
# mega.head.drop = nn.Identity()
# mega.head.fc = nn.Identity()

# %% [markdown]
# ### 测试输出

# %%
mega.to(device)
test_input = torch.ones(4, 3, 384, 384)
test_input = test_input.to(device)
with torch.no_grad():
    test_output = mega(test_input)
print(test_output.shape)
# Out:
# torch.Size([4, 1536])

# %%
# from sklearn.preprocessing import LabelEncoder
root = '/kaggle/input/animal-clef-2025'
# Loading the dataset
dataset = AnimalCLEF2025(root, transform=transform, load_label=True)
# data fillna
dataset.metadata.loc[dataset.metadata['species'].isna(), 'species'] = 'salamander'
dataset_database = dataset.get_subset(dataset.metadata['split'] == 'database')
dataset_query = dataset.get_subset(dataset.metadata['split'] == 'query')
n_query = len(dataset_query)

# %%
# # transform label
# df_database = dataset_database.df
# df_database['name'] = df_database['identity'].copy()
# encoder = LabelEncoder()
# df_database['identity'] = encoder.fit_transform(df_database['identity'])
# dataset_database.df = df_database

# %%
# df_database.to_csv("/kaggle/working/mm.csv", index=False, encoding='utf-8-sig')

# %%
# split
# availableSet & testSet
df_database = dataset_database.df
from wildlife_datasets import splits
openSplitter = splits.OpenSetSplit(0.9, 0.1, seed=333)
for idx_train, idx_test in openSplitter.split(df_database):
    splits.analyze_split(df_database, idx_train, idx_test)
df_train, df_test = df_database.loc[idx_train], df_database.loc[idx_test]
availableSet = dataset_database.get_subset(df_train.index)
testSet = dataset_database.get_subset(df_test.index)
df_availableSet = availableSet.df

# trainSet & thresholdSet
openSplitter = splits.OpenSetSplit(0.9, 0.1, seed=333)
for idx_train, idx_test in openSplitter.split(df_availableSet):
    splits.analyze_split(df_availableSet, idx_train, idx_test)
df_train, df_test = df_availableSet.loc[idx_train], df_availableSet.loc[idx_test]
trainSet = availableSet.get_subset(df_train.index)
thresholdSet = availableSet.get_subset(df_test.index)
df_database_training = trainSet.df

# training & test 
closeSplitter = splits.ClosedSetSplit(0.9, seed=333)
for idx_train, idx_test in closeSplitter.split(df_database_training):
    splits.analyze_split(df_database_training, idx_train, idx_test)
df_training, df_val = df_database_training.loc[idx_train], df_database_training.loc[idx_test]
training = trainSet.get_subset(df_training.index)
test = trainSet.get_subset(df_val.index)
# Out:
# Split: time-unaware open-set
# Samples: train/test/unassigned/total = 11041/2033/0/13074
# Classes: train/test/unassigned/total = 1006/814/0/1102
# Samples: train only/test only        = 288/1315
# Classes: train only/test only/joint  = 288/96/718
#
# Fraction of train set     = 84.45%
# Fraction of test set only = 10.06%
# Split: time-unaware open-set
# Samples: train/test/unassigned/total = 9363/1678/0/11041
# Classes: train/test/unassigned/total = 919/645/0/1006
# Samples: train only/test only        = 361/1120
# Classes: train only/test only/joint  = 361/87/558
#
# Fraction of train set     = 84.80%
# Fraction of test set only = 10.14%
# Split: time-unaware closed-set
# Samples: train/test/unassigned/total = 8341/1022/0/9363
# Classes: train/test/unassigned/total = 919/492/0/919
# Samples: train only/test only        = 427/0
# Classes: train only/test only/joint  = 427/0/492
#
# Fraction of train set     = 89.08%
# Fraction of test set only = 0.00%

# %%
from wildlife_tools.similarity import CosineSimilarity
from wildlife_tools.similarity.wildfusion import SimilarityPipeline, WildFusion
from wildlife_tools.similarity.pairwise.lightglue import MatchLightGlue
from wildlife_tools.features.local import AlikedExtractor
from wildlife_tools.similarity.calibration import IsotonicCalibration
device = 'cuda'
transforms_aliked = T.Compose([
    T.Resize([512, 512]),
    GammaCorrection(gamma=0.5),
    T.ToTensor()
])
matcher_aliked = SimilarityPipeline(
    matcher = MatchLightGlue(features='aliked', device=device, batch_size=16),
    extractor = AlikedExtractor(),
    transform = transforms_aliked,
    calibration = IsotonicCalibration()
)

matcher_mega = SimilarityPipeline(
    matcher = CosineSimilarity(),
    extractor = DeepFeatures(model=mega, device=device, batch_size=16),
    transform = transform,
    calibration = IsotonicCalibration()
)

dataset_calibration = AnimalCLEF2025(root, df=dataset_database.metadata[:100], load_label=True)

wildfusion_submission = WildFusion(calibrated_pipelines = [matcher_aliked, matcher_mega], priority_pipeline = matcher_mega)
wildfusion_submission.fit_calibration(dataset_calibration, dataset_calibration)

similarity = wildfusion_submission(thresholdSet, training, B=23)
# Out:
# /usr/local/lib/python3.11/dist-packages/lightglue/lightglue.py:24: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @torch.cuda.amp.custom_fwd(cast_inputs=torch.float32)
# Downloading: "https://github.com/cvg/LightGlue/releases/download/v0.1_arxiv/aliked_lightglue.pth" to /root/.cache/torch/hub/checkpoints/aliked_lightglue_v0-1_arxiv.pth
# 100%|██████████| 45.4M/45.4M [00:00<00:00, 143MB/s]
# Downloading: "https://github.com/Shiaoming/ALIKED/raw/main/models/aliked-n16.pth" to /root/.cache/torch/hub/checkpoints/aliked-n16.pth
# 100%|██████████| 2.61M/2.61M [00:00<00:00, 43.4MB/s]
# 100%|█████████████████████████████████████████████████████████████| 100/100 [00:04<00:00, 20.97it/s]
# 100%|█████████████████████████████████████████████████████████████| 100/100 [00:03<00:00, 26.75it/s]
# 100%|█████████████████████████████████████████████████████████████| 625/625 [00:44<00:00, 13.97it/s]
# 100%|█████████████████████████████████████████████████████████████████| 7/7 [00:06<00:00,  1.11it/s]
# 100%|█████████████████████████████████████████████████████████████████| 7/7 [00:06<00:00,  1.01it/s]
# 100%|█████████████████████████████████████████████████████████████████| 7/7 [00:06<00:00,  1.01it/s]
# 100%|█████████████████████████████████████████████████████████████████| 7/7 [00:07<00:00,  1.04s/it]
# 100%|█████████████████████████████████████████████████████████████| 105/105 [01:38<00:00,  1.06it/s]
# 100%|█████████████████████████████████████████████████████████████| 522/522 [07:40<00:00,  1.13it/s]
# 100%|███████████████████████████████████████████████████████████| 1678/1678 [00:43<00:00, 38.35it/s]
# 100%|███████████████████████████████████████████████████████████| 8341/8341 [03:21<00:00, 41.47it/s]
# 100%|███████████████████████████████████████████████████████████| 2413/2413 [02:53<00:00, 13.91it/s]
# 100%|█████████████████████████████████████████████████████████████| 105/105 [01:28<00:00,  1.19it/s]
# 100%|█████████████████████████████████████████████████████████████| 522/522 [06:56<00:00,  1.25it/s]

# %%
similarity.shape
# Out:
# (1678, 8341)

# %%
n_query = len(thresholdSet)
pred_idx_threshold = similarity.argsort(axis=1)[:,-1]
pred_scores_threshold = similarity[range(n_query), pred_idx_threshold]

# %%
pred_scores_threshold.shape
# Out:
# (1678,)

# %%
# Get species indices
lynx_indices = thresholdSet.df[thresholdSet.df['species'] == 'lynx'].index
loggerhead_indices = thresholdSet.df[thresholdSet.df['species'] == 'loggerhead turtle'].index
salamander_indices = thresholdSet.df[thresholdSet.df['species'] == 'salamander'].index

# Get prediction indices
pred_idx_threshold_lynx = pred_idx_threshold[lynx_indices]
pred_idx_threshold_loggerhead = pred_idx_threshold[loggerhead_indices]
pred_idx_threshold_salamander = pred_idx_threshold[salamander_indices]

# Get prediction scores
pred_scores_threshold_lynx = pred_scores_threshold[lynx_indices]
pred_scores_threshold_loggerhead = pred_scores_threshold[loggerhead_indices]
pred_scores_threshold_salamander = pred_scores_threshold[salamander_indices]

# %%
unseen_ids_threshold = []
all_ids = df_database['identity'].unique()

for i in all_ids:
    if i in thresholdSet.metadata['identity'].tolist():
        if i not in training.metadata['identity'].tolist():
            # if not in the training set, the id in test set havent been seen before
            unseen_ids_threshold.append(i)

# %%
thresholdSet_true_labels = thresholdSet.labels_string.astype(str)
unseen_ids_threshold = pd.Series(unseen_ids_threshold).astype(str)
thresholds = np.arange(0, 1, 0.01)
results = []
labels = np.array(training.labels_string)


for threshold in thresholds:
    predictions = labels[pred_idx_threshold].copy()
    #print(predictions[1])
    predictions[pred_scores_threshold < threshold] = 'new_individual'

    baks = baks_compute(thresholdSet_true_labels, predictions, unseen_ids_threshold)
    baus = baus_compute(thresholdSet_true_labels, predictions, unseen_ids_threshold, 'new_individual')
    geo_mean = compute_geometric_mean(baks, baus)
    results.append((threshold, baks, baus, geo_mean))

    print(f"Threshold: {threshold:.2f} | BAKS: {baks:.4f} | BAUS: {baus:.4f} | GEO_MEAN: {geo_mean:.4f}")
    
# comment: increase the threshold can lead to the increase of baus and decrease of baks
# Out:
# Threshold: 0.00 | BAKS: 0.5986 | BAUS: 0.0000 | GEO_MEAN: 0.0000
# Threshold: 0.01 | BAKS: 0.5986 | BAUS: 0.0000 | GEO_MEAN: 0.0000
# Threshold: 0.02 | BAKS: 0.5986 | BAUS: 0.0000 | GEO_MEAN: 0.0000
# Threshold: 0.03 | BAKS: 0.5986 | BAUS: 0.0000 | GEO_MEAN: 0.0000
# Threshold: 0.04 | BAKS: 0.5986 | BAUS: 0.0000 | GEO_MEAN: 0.0000
# Threshold: 0.05 | BAKS: 0.5986 | BAUS: 0.0000 | GEO_MEAN: 0.0000
# Threshold: 0.06 | BAKS: 0.5968 | BAUS: 0.0088 | GEO_MEAN: 0.0724
# Threshold: 0.07 | BAKS: 0.5932 | BAUS: 0.0476 | GEO_MEAN: 0.1680
# Threshold: 0.08 | BAKS: 0.5878 | BAUS: 0.0753 | GEO_MEAN: 0.2104
# Threshold: 0.09 | BAKS: 0.5842 | BAUS: 0.1545 | GEO_MEAN: 0.3005
# Threshold: 0.10 | BAKS: 0.5735 | BAUS: 0.2561 | GEO_MEAN: 0.3833
# Threshold: 0.11 | BAKS: 0.5627 | BAUS: 0.3687 | GEO_MEAN: 0.4555
# Threshold: 0.12 | BAKS: 0.5591 | BAUS: 0.4207 | GEO_MEAN: 0.4850
# Threshold: 0.13 | BAKS: 0.5556 | BAUS: 0.4628 | GEO_MEAN: 0.5071
# Threshold: 0.14 | BAKS: 0.5502 | BAUS: 0.5041 | GEO_MEAN: 0.5266
# Threshold: 0.15 | BAKS: 0.5484 | BAUS: 0.5542 | GEO_MEAN: 0.5513
# Threshold: 0.16 | BAKS: 0.5466 | BAUS: 0.5658 | GEO_MEAN: 0.5561
# Threshold: 0.17 | BAKS: 0.5430 | BAUS: 0.6140 | GEO_MEAN: 0.5774
# Threshold: 0.18 | BAKS: 0.5430 | BAUS: 0.6361 | GEO_MEAN: 0.5877
# Threshold: 0.19 | BAKS: 0.5412 | BAUS: 0.6746 | GEO_MEAN: 0.6042
# Threshold: 0.20 | BAKS: 0.5358 | BAUS: 0.6793 | GEO_MEAN: 0.6033
# Threshold: 0.21 | BAKS: 0.5358 | BAUS: 0.7046 | GEO_MEAN: 0.6144
# Threshold: 0.22 | BAKS: 0.5323 | BAUS: 0.7141 | GEO_MEAN: 0.6165
# Threshold: 0.23 | BAKS: 0.5287 | BAUS: 0.7314 | GEO_MEAN: 0.6218
# Threshold: 0.24 | BAKS: 0.5269 | BAUS: 0.7824 | GEO_MEAN: 0.6420
# Threshold: 0.25 | BAKS: 0.5215 | BAUS: 0.8307 | GEO_MEAN: 0.6582
# Threshold: 0.26 | BAKS: 0.5179 | BAUS: 0.8777 | GEO_MEAN: 0.6742
# Threshold: 0.27 | BAKS: 0.5179 | BAUS: 0.9131 | GEO_MEAN: 0.6877
# Threshold: 0.89 | BAKS: 0.1219 | BAUS: 1.0000 | GEO_MEAN: 0.3491
# Threshold: 0.90 | BAKS: 0.1111 | BAUS: 1.0000 | GEO_MEAN: 0.3333
# Threshold: 0.91 | BAKS: 0.1022 | BAUS: 1.0000 | GEO_MEAN: 0.3196
# Threshold: 0.92 | BAKS: 0.0914 | BAUS: 1.0000 | GEO_MEAN: 0.3023
# Threshold: 0.93 | BAKS: 0.0789 | BAUS: 1.0000 | GEO_MEAN: 0.2808
# Threshold: 0.94 | BAKS: 0.0591 | BAUS: 1.0000 | GEO_MEAN: 0.2432
# Threshold: 0.95 | BAKS: 0.0376 | BAUS: 1.0000 | GEO_MEAN: 0.1940
# Threshold: 0.96 | BAKS: 0.0287 | BAUS: 1.0000 | GEO_MEAN: 0.1693
# Threshold: 0.97 | BAKS: 0.0179 | BAUS: 1.0000 | GEO_MEAN: 0.1339
# Threshold: 0.98 | BAKS: 0.0108 | BAUS: 1.0000 | GEO_MEAN: 0.1037
# Threshold: 0.99 | BAKS: 0.0018 | BAUS: 1.0000 | GEO_MEAN: 0.0423

# %%
# First get the filtered labels for each species
thresholdSet_true_labels_lynx = thresholdSet_true_labels[lynx_indices]
thresholdSet_true_labels_loggerhead = thresholdSet_true_labels[loggerhead_indices]
thresholdSet_true_labels_salamander = thresholdSet_true_labels[salamander_indices]

# Filter unseen_ids for each species
unseen_ids_threshold_lynx =  [str(x) for x in unseen_ids_threshold]
unseen_ids_threshold_loggerhead =  [str(x) for x in unseen_ids_threshold]
unseen_ids_threshold_salamander =  [str(x) for x in unseen_ids_threshold]

# Version for Lynx
def evaluate_lynx_thresholds():
    thresholds = np.arange(0, 1, 0.01)
    results_lynx = []
    labels = np.array(training.labels_string)

    print("Evaluating Lynx:")
    for threshold in thresholds:
        predictions = labels[pred_idx_threshold_lynx].copy()
        predictions[pred_scores_threshold_lynx < threshold] = 'new_individual'

        baks = baks_compute(thresholdSet_true_labels_lynx, predictions, unseen_ids_threshold_lynx)
        baus = baus_compute(thresholdSet_true_labels_lynx, predictions, unseen_ids_threshold_lynx, 'new_individual')
        geo_mean = compute_geometric_mean(baks, baus)
        results_lynx.append((threshold, baks, baus, geo_mean))

        print(f"Threshold: {threshold:.2f} | BAKS: {baks:.4f} | BAUS: {baus:.4f} | GEO_MEAN: {geo_mean:.4f}")
    return results_lynx

# Version for Loggerhead Turtle
def evaluate_loggerhead_thresholds():
    thresholds = np.arange(0, 1, 0.01)
    results_loggerhead = []
    labels = np.array(training.labels_string)

    print("\nEvaluating Loggerhead Turtle:")
    for threshold in thresholds:
        predictions = labels[pred_idx_threshold_loggerhead].copy()
        predictions[pred_scores_threshold_loggerhead < threshold] = 'new_individual'

        baks = baks_compute(thresholdSet_true_labels_loggerhead, predictions, unseen_ids_threshold_loggerhead)
        baus = baus_compute(thresholdSet_true_labels_loggerhead, predictions, unseen_ids_threshold_loggerhead, 'new_individual')
        geo_mean = compute_geometric_mean(baks, baus)
        results_loggerhead.append((threshold, baks, baus, geo_mean))

        print(f"Threshold: {threshold:.2f} | BAKS: {baks:.4f} | BAUS: {baus:.4f} | GEO_MEAN: {geo_mean:.4f}")
    return results_loggerhead

# Version for Salamander
def evaluate_salamander_thresholds():
    thresholds = np.arange(0, 1, 0.01)
    results_salamander = []
    labels = np.array(training.labels_string)

    print("\nEvaluating Salamander:")
    for threshold in thresholds:
        predictions = labels[pred_idx_threshold_salamander].copy()
        predictions[pred_scores_threshold_salamander < threshold] = 'new_individual'

        baks = baks_compute(thresholdSet_true_labels_salamander, predictions, unseen_ids_threshold_salamander)
        baus = baus_compute(thresholdSet_true_labels_salamander, predictions, unseen_ids_threshold_salamander, 'new_individual')
        geo_mean = compute_geometric_mean(baks, baus)
        results_salamander.append((threshold, baks, baus, geo_mean))

        print(f"Threshold: {threshold:.2f} | BAKS: {baks:.4f} | BAUS: {baus:.4f} | GEO_MEAN: {geo_mean:.4f}")
    return results_salamander

# Run evaluations
results_lynx = evaluate_lynx_thresholds()
results_loggerhead = evaluate_loggerhead_thresholds()
results_salamander = evaluate_salamander_thresholds()

# Optional: Plot results for comparison
def plot_results(results_lynx, results_loggerhead, results_salamander):
    import matplotlib.pyplot as plt
    
    fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(15, 5))
    
    for results, ax, title in zip([results_lynx, results_loggerhead, results_salamander], 
                                [ax1, ax2, ax3],
                                ['Lynx', 'Loggerhead Turtle', 'Salamander']):
        thresholds = [r[0] for r in results]
        baks = [r[1] for r in results]
        baus = [r[2] for r in results]
        geo_mean = [r[3] for r in results]
        
        ax.plot(thresholds, baks, label='BAKS')
        ax.plot(thresholds, baus, label='BAUS')
        ax.plot(thresholds, geo_mean, label='GEO_MEAN')
        ax.set_title(title)
        ax.set_xlabel('Threshold')
        ax.set_ylabel('Score')
        ax.legend()
        ax.grid(True)
    
    plt.tight_layout()
    plt.show()

# Plot the results
plot_results(results_lynx, results_loggerhead, results_salamander)
# Out:
# Evaluating Lynx:
# Threshold: 0.00 | BAKS: 0.5185 | BAUS: 0.0000 | GEO_MEAN: 0.0000
# Threshold: 0.01 | BAKS: 0.5185 | BAUS: 0.0000 | GEO_MEAN: 0.0000
# Threshold: 0.02 | BAKS: 0.5185 | BAUS: 0.0000 | GEO_MEAN: 0.0000
# Threshold: 0.03 | BAKS: 0.5185 | BAUS: 0.0000 | GEO_MEAN: 0.0000
# Threshold: 0.04 | BAKS: 0.5185 | BAUS: 0.0000 | GEO_MEAN: 0.0000
# Threshold: 0.05 | BAKS: 0.5185 | BAUS: 0.0000 | GEO_MEAN: 0.0000
# Threshold: 0.06 | BAKS: 0.5185 | BAUS: 0.0000 | GEO_MEAN: 0.0000
# Threshold: 0.07 | BAKS: 0.4815 | BAUS: 0.0134 | GEO_MEAN: 0.0803
# Threshold: 0.08 | BAKS: 0.4815 | BAUS: 0.0553 | GEO_MEAN: 0.1632
# Threshold: 0.09 | BAKS: 0.4815 | BAUS: 0.1171 | GEO_MEAN: 0.2374
# Threshold: 0.10 | BAKS: 0.4815 | BAUS: 0.2303 | GEO_MEAN: 0.3330
# Threshold: 0.11 | BAKS: 0.4815 | BAUS: 0.3390 | GEO_MEAN: 0.4040
# Threshold: 0.12 | BAKS: 0.4815 | BAUS: 0.3663 | GEO_MEAN: 0.4200
# Threshold: 0.13 | BAKS: 0.4815 | BAUS: 0.4192 | GEO_MEAN: 0.4492
# Threshold: 0.14 | BAKS: 0.4630 | BAUS: 0.4499 | GEO_MEAN: 0.4564
# Threshold: 0.15 | BAKS: 0.4630 | BAUS: 0.4836 | GEO_MEAN: 0.4732
